# %% [markdown]
# # extracttion des données de logement de l'ademe via l'api

# %% [markdown]
# ## I- extractions des données existants

# %%
import requests
import pandas as pd
import concurrent.futures
import os
import time

# %%
import requests
import pandas as pd
import concurrent.futures
import os
import time

# === CONFIG ===
BASE_URL = "https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines"
CODES_POSTAUX_FILE = "adresses-69.csv"   # fichier contenant une colonne "code_postal"
OUTPUT_FILE = "data_existants_69.csv"

# Charger les codes postaux du département
code_postaux_df = pd.read_csv(CODES_POSTAUX_FILE, dtype=str, sep=';')
code_postals = code_postaux_df['code_postal'].unique().tolist()

# Colonnes à extraire
listeColumn = "configuration_installation_chauffage_n1,conso_chauffage_installation_chauffage_n1,type_generateur_n1_ecs_n1,numero_voie_ban,score_ban,surface_habitable_immeuble," \
"conso_auxiliaires_ep,deperditions_murs,cout_eclairage,conso_auxiliaires_ef,statut_geocodage,ventilation_posterieure_2012,cout_chauffage,conso_5_usages_par_m2_ep,date_etablissement_dpe," \
"conso_ecs_ef_energie_n1,conso_ecs_ef_energie_n2,emission_ges_chauffage,description_installation_chauffage_n1,conso_5_usages_par_m2_ef,cout_ecs_energie_n2,conso_chauffage_ef_energie_n1," \
"conso_chauffage_ef_energie_n2,qualite_isolation_menuiseries,cout_total_5_usages_energie_n2,date_reception_dpe,cout_total_5_usages_energie_n1,cout_ecs_energie_n1,qualite_isolation_plancher_bas," \
"modele_dpe,qualite_isolation_enveloppe,conso_chauffage_generateur_n1_installation_n1,type_energie_n1,emission_ges_eclairage,type_energie_n2,code_postal_ban,emission_ges_ecs,conso_5_usages_ef_energie_n2," \
"conso_5_usages_ef,conso_5_usages_ef_energie_n1,code_insee_ban,deperditions_planchers_bas,conso_5_usages_ep,date_fin_validite_dpe,deperditions_enveloppe,code_region_ban,volume_stockage_generateur_n1_ecs_n1," \
"surface_chauffee_installation_chauffage_n1,version_dpe,besoin_ecs,coordonnee_cartographique_x_ban,type_generateur_chauffage_principal,type_energie_principale_ecs,apport_solaire_saison_chauffe,adresse_ban," \
"nombre_appartement,deperditions_renouvellement_air,_rand,surface_habitable_desservie_par_installation_ecs_n1,production_electricite_pv_kwhep_par_an,type_installation_chauffage,nombre_niveau_logement," \
"surface_habitable_logement,cout_ecs,type_installation_ecs_n1,emission_ges_5_usages_energie_n1,emission_ges_5_usages_energie_n2,apport_interne_saison_froide,emission_ges_5_usages_par_m2," \
"description_generateur_chauffage_n1_installation_n1,qualite_isolation_plancher_haut_comble_perdu,apport_interne_saison_chauffe,apport_solaire_saison_froide,type_generateur_n1_installation_n1," \
"nombre_logements_desservis_par_installation_ecs_n1,complement_adresse_logement,cout_auxiliaires,type_emetteur_installation_chauffage_n1,besoin_chauffage,configuration_installation_ecs_n1,description_installation_ecs_n1," \
"classe_inertie_batiment,deperditions_ponts_thermiques,type_generateur_chauffage_principal_ecs,emission_ges_refroidissement,hauteur_sous_plafond,conso_chauffage_ef,nom_commune_ban,annee_construction,_geopoint,date_visite_diagnostiqueur," \
"type_batiment,periode_construction,type_installation_ecs,conso_ecs_ep,conso_ecs_ef,emission_ges_5_usages,date_derniere_modification_dpe,etiquette_ges,identifiant_ban,deperditions_baies_vitrees,type_energie_generateur_n1_ecs_n1,ubat_w_par_m2_k," \
"numero_etage_appartement,nom_commune_brut,conso_ef_installation_ecs_n1,etiquette_dpe,description_generateur_n1_ecs_n1,code_departement_ban,type_installation_chauffage_n1,methode_application_dpe,adresse_brut,cout_total_5_usages,categorie_enr," \
"conso_refroidissement_ef,conso_eclairage_ef,deperditions_planchers_hauts,zone_climatique,conso_ef_generateur_n1_ecs_n1,emission_ges_ecs_energie_n1,emission_ges_ecs_energie_n2,cout_refroidissement,conso_chauffage_ep,conso_eclairage_ep,usage_generateur_n1_installation_n1," \
"nom_rue_ban,qualite_isolation_murs,type_installation_solaire_n1,classe_altitude,conso_refroidissement_ep,type_energie_principale_chauffage,numero_dpe,_i,besoin_refroidissement,emission_ges_chauffage_energie_n2,emission_ges_chauffage_energie_n1,cout_chauffage_energie_n2," \
"deperditions_portes,cout_chauffage_energie_n1,coordonnee_cartographique_y_ban,type_energie_generateur_n1_installation_n1,code_postal_brut,emission_ges_auxiliaires,usage_generateur_n1_ecs_n1"

# Supprimer ancien fichier s'il existe
if os.path.exists(OUTPUT_FILE):
    os.remove(OUTPUT_FILE)

all_results = []

def fetch_data_smart(code_postal, etiquette=None, start_date=None, end_date=None):
    results = []
    size = 1000
    page = 1

    # Construction du filtre q
    q_parts = [f"code_postal_ban:{code_postal}"]
    if etiquette:
        q_parts.append(f"etiquette_dpe:{etiquette}")
    if start_date and end_date:
        q_parts.append(f"date_reception_dpe:[{start_date} TO {end_date}]")
    q_filter = " AND ".join(q_parts)

    print(f"\n--- Début téléchargement : {q_filter} ---")

    # Première requête pour connaître le total
    params = {"page": 1, "size": size, "qs": q_filter, "select": listeColumn, "q_fields": "code_postal_ban,etiquette_dpe,date_reception_dpe"}
    response = requests.get(BASE_URL, params=params)
    if response.status_code != 200:
        print(f" Erreur {response.status_code} pour {q_filter}")
        return results

    data = response.json()
    total = data.get("total", 0)
    print(f"Total estimé pour {q_filter} : {total}")

    # Si total > 1000 et pas encore filtré par etiquette
    if total > 10000 and etiquette is None:
        print(f"Nombre trop élevé ({total}), découpage par étiquette...")
        etiquettes = ["A", "B", "C", "D", "E", "F", "G"]
        for etiq in etiquettes:
            results.extend(fetch_data_smart(code_postal, etiquette=etiq))
        return results

    # Si total > 1000 et déjà filtré par etiquette mais pas par date
    if total > 10000 and etiquette is not None and start_date is None:
        print(f"Nombre trop élevé ({total}) pour {code_postal} et étiquette {etiquette}, découpage par année...")
        for year in range(2021, 2025):  # exemple années 2021 à 2024
            year_start = f"{year}-01-01"
            year_end = f"{year}-12-31"
            results.extend(fetch_data_smart(code_postal, etiquette, year_start, year_end))
        return results

    # Sinon récupération normale par page
    while True:
        params["page"] = page
        response = requests.get(BASE_URL, params=params)
        if response.status_code != 200:
            print(f" Erreur {response.status_code} page {page} pour {q_filter}")
            break

        page_results = response.json().get("results", [])
        if not page_results:
            print(f" Aucun résultat à la page {page}, arrêt.")
            break

        results.extend(page_results)
        print(f"{q_filter} Page {page} : {len(page_results)} résultats — cumul : {len(results)}/{total}")

        if len(page_results) < size:
            print(f" Dernière page atteinte pour {q_filter}")
            break

        page += 1
        time.sleep(3)

    print(f"--- Fin téléchargement : {q_filter} — {len(results)} DPE récupérés ---\n")
    return results

all_results = []
for cp in code_postals:
    all_results.extend(fetch_data_smart(cp))

df = pd.DataFrame(all_results)
df.to_csv("data_existants_69.csv", index=False, encoding='utf-8')
print(f"Export terminé : data_existants_69.csv ({len(df)} lignes)")


#df = pd.DataFrame(all_results)
#df.to_csv("data_existants_69.csv", index=False, encoding='utf-8')
#print(f" Export terminé : data_existants_69.csv ({len(df)} lignes)")
# Out:
# --- Début téléchargement : code_postal_ban:69790 ---
# Total estimé pour code_postal_ban:69790 : 200
# code_postal_ban:69790 Page 1 : 200 résultats — cumul : 200/200
#  Dernière page atteinte pour code_postal_ban:69790
# --- Fin téléchargement : code_postal_ban:69790 — 200 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69170 ---
# Total estimé pour code_postal_ban:69170 : 2928
# code_postal_ban:69170 Page 1 : 1000 résultats — cumul : 1000/2928
# code_postal_ban:69170 Page 2 : 1000 résultats — cumul : 2000/2928
# code_postal_ban:69170 Page 3 : 928 résultats — cumul : 2928/2928
#  Dernière page atteinte pour code_postal_ban:69170
# --- Fin téléchargement : code_postal_ban:69170 — 2928 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69250 ---
# Total estimé pour code_postal_ban:69250 : 3222
# code_postal_ban:69250 Page 1 : 1000 résultats — cumul : 1000/3222
# code_postal_ban:69250 Page 2 : 1000 résultats — cumul : 2000/3222
# code_postal_ban:69250 Page 3 : 1000 résultats — cumul : 3000/3222
# code_postal_ban:69250 Page 4 : 222 résultats — cumul : 3222/3222
#  Dernière page atteinte pour code_postal_ban:69250
# --- Fin téléchargement : code_postal_ban:69250 — 3222 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69380 ---
# Total estimé pour code_postal_ban:69380 : 3277
# code_postal_ban:69380 Page 1 : 1000 résultats — cumul : 1000/3277
# code_postal_ban:69380 Page 2 : 1000 résultats — cumul : 2000/3277
# code_postal_ban:69380 Page 3 : 1000 résultats — cumul : 3000/3277
# code_postal_ban:69380 Page 4 : 277 résultats — cumul : 3277/3277
#  Dernière page atteinte pour code_postal_ban:69380
# --- Fin téléchargement : code_postal_ban:69380 — 3277 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 ---
# Total estimé pour code_postal_ban:69009 : 21264
# Nombre trop élevé (21264), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:A : 1
# code_postal_ban:69009 AND etiquette_dpe:A Page 1 : 1 résultats — cumul : 1/1
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:A — 1 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:B : 530
# code_postal_ban:69009 AND etiquette_dpe:B Page 1 : 530 résultats — cumul : 530/530
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:B — 530 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:C : 10425
# Nombre trop élevé (10425) pour 69009 et étiquette C, découpage par année...
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] : 212
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] Page 1 : 212 résultats — cumul : 212/212
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31]
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] — 212 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] : 1300
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 1 : 1000 résultats — cumul : 1000/1300
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 2 : 300 résultats — cumul : 1300/1300
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31]
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] — 1300 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] : 5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 1 : 1000 résultats — cumul : 1000/5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 2 : 1000 résultats — cumul : 2000/5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 3 : 1000 résultats — cumul : 3000/5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 4 : 1000 résultats — cumul : 4000/5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 5 : 1000 résultats — cumul : 5000/5747
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 6 : 747 résultats — cumul : 5747/5747
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31]
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] — 5747 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] : 1816
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 1 : 1000 résultats — cumul : 1000/1816
# code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 2 : 816 résultats — cumul : 1816/1816
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31]
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] — 1816 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:D : 5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 5 : 1000 résultats — cumul : 5000/5566
# code_postal_ban:69009 AND etiquette_dpe:D Page 6 : 566 résultats — cumul : 5566/5566
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:D — 5566 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:E : 3479
# code_postal_ban:69009 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/3479
# code_postal_ban:69009 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/3479
# code_postal_ban:69009 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/3479
# code_postal_ban:69009 AND etiquette_dpe:E Page 4 : 479 résultats — cumul : 3479/3479
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:E — 3479 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:F : 789
# code_postal_ban:69009 AND etiquette_dpe:F Page 1 : 789 résultats — cumul : 789/789
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:F — 789 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69009 AND etiquette_dpe:G : 474
# code_postal_ban:69009 AND etiquette_dpe:G Page 1 : 474 résultats — cumul : 474/474
#  Dernière page atteinte pour code_postal_ban:69009 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69009 AND etiquette_dpe:G — 474 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 ---
# Total estimé pour code_postal_ban:69008 : 25293
# Nombre trop élevé (25293), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:A : 12
# code_postal_ban:69008 AND etiquette_dpe:A Page 1 : 12 résultats — cumul : 12/12
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:A — 12 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:B : 1094
# code_postal_ban:69008 AND etiquette_dpe:B Page 1 : 1000 résultats — cumul : 1000/1094
# code_postal_ban:69008 AND etiquette_dpe:B Page 2 : 94 résultats — cumul : 1094/1094
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:B — 1094 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:C : 10108
# Nombre trop élevé (10108) pour 69008 et étiquette C, découpage par année...
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] : 447
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] Page 1 : 447 résultats — cumul : 447/447
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31]
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] — 447 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] : 1397
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 1 : 1000 résultats — cumul : 1000/1397
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 2 : 397 résultats — cumul : 1397/1397
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31]
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] — 1397 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] : 2573
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 1 : 1000 résultats — cumul : 1000/2573
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 2 : 1000 résultats — cumul : 2000/2573
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 3 : 573 résultats — cumul : 2573/2573
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31]
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] — 2573 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] : 3841
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 1 : 1000 résultats — cumul : 1000/3841
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 2 : 1000 résultats — cumul : 2000/3841
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 3 : 1000 résultats — cumul : 3000/3841
# code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 4 : 841 résultats — cumul : 3841/3841
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31]
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] — 3841 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:D : 7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 5 : 1000 résultats — cumul : 5000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 6 : 1000 résultats — cumul : 6000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 7 : 1000 résultats — cumul : 7000/7994
# code_postal_ban:69008 AND etiquette_dpe:D Page 8 : 994 résultats — cumul : 7994/7994
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:D — 7994 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:E : 4192
# code_postal_ban:69008 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/4192
# code_postal_ban:69008 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/4192
# code_postal_ban:69008 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/4192
# code_postal_ban:69008 AND etiquette_dpe:E Page 4 : 1000 résultats — cumul : 4000/4192
# code_postal_ban:69008 AND etiquette_dpe:E Page 5 : 192 résultats — cumul : 4192/4192
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:E — 4192 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:F : 1239
# code_postal_ban:69008 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1239
# code_postal_ban:69008 AND etiquette_dpe:F Page 2 : 239 résultats — cumul : 1239/1239
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:F — 1239 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69008 AND etiquette_dpe:G : 654
# code_postal_ban:69008 AND etiquette_dpe:G Page 1 : 654 résultats — cumul : 654/654
#  Dernière page atteinte pour code_postal_ban:69008 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69008 AND etiquette_dpe:G — 654 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 ---
# Total estimé pour code_postal_ban:69006 : 15721
# Nombre trop élevé (15721), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:A : 5
# code_postal_ban:69006 AND etiquette_dpe:A Page 1 : 5 résultats — cumul : 5/5
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:A — 5 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:B : 162
# code_postal_ban:69006 AND etiquette_dpe:B Page 1 : 162 résultats — cumul : 162/162
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:B — 162 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:C : 3147
# code_postal_ban:69006 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/3147
# code_postal_ban:69006 AND etiquette_dpe:C Page 2 : 1000 résultats — cumul : 2000/3147
# code_postal_ban:69006 AND etiquette_dpe:C Page 3 : 1000 résultats — cumul : 3000/3147
# code_postal_ban:69006 AND etiquette_dpe:C Page 4 : 147 résultats — cumul : 3147/3147
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:C
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:C — 3147 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:D : 6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 5 : 1000 résultats — cumul : 5000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 6 : 1000 résultats — cumul : 6000/6235
# code_postal_ban:69006 AND etiquette_dpe:D Page 7 : 235 résultats — cumul : 6235/6235
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:D — 6235 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:E : 3951
# code_postal_ban:69006 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/3951
# code_postal_ban:69006 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/3951
# code_postal_ban:69006 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/3951
# code_postal_ban:69006 AND etiquette_dpe:E Page 4 : 951 résultats — cumul : 3951/3951
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:E — 3951 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:F : 1389
# code_postal_ban:69006 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1389
# code_postal_ban:69006 AND etiquette_dpe:F Page 2 : 389 résultats — cumul : 1389/1389
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:F — 1389 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69006 AND etiquette_dpe:G : 832
# code_postal_ban:69006 AND etiquette_dpe:G Page 1 : 832 résultats — cumul : 832/832
#  Dernière page atteinte pour code_postal_ban:69006 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69006 AND etiquette_dpe:G — 832 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 ---
# Total estimé pour code_postal_ban:69007 : 33550
# Nombre trop élevé (33550), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:A : 51
# code_postal_ban:69007 AND etiquette_dpe:A Page 1 : 51 résultats — cumul : 51/51
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:A — 51 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:B : 790
# code_postal_ban:69007 AND etiquette_dpe:B Page 1 : 790 résultats — cumul : 790/790
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:B — 790 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:C : 13933
# Nombre trop élevé (13933) pour 69007 et étiquette C, découpage par année...
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] : 459
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] Page 1 : 459 résultats — cumul : 459/459
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] — 459 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] : 2394
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 1 : 1000 résultats — cumul : 1000/2394
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 2 : 1000 résultats — cumul : 2000/2394
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 3 : 394 résultats — cumul : 2394/2394
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] — 2394 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] : 4707
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 1 : 1000 résultats — cumul : 1000/4707
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 2 : 1000 résultats — cumul : 2000/4707
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 3 : 1000 résultats — cumul : 3000/4707
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 4 : 1000 résultats — cumul : 4000/4707
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 5 : 707 résultats — cumul : 4707/4707
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] — 4707 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] : 3518
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 1 : 1000 résultats — cumul : 1000/3518
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 2 : 1000 résultats — cumul : 2000/3518
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 3 : 1000 résultats — cumul : 3000/3518
# code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 4 : 518 résultats — cumul : 3518/3518
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:C AND date_reception_dpe:[2024-01-01 TO 2024-12-31] — 3518 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:D : 10603
# Nombre trop élevé (10603) pour 69007 et étiquette D, découpage par année...
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2021-01-01 TO 2021-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2021-01-01 TO 2021-12-31] : 562
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2021-01-01 TO 2021-12-31] Page 1 : 562 résultats — cumul : 562/562
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2021-01-01 TO 2021-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2021-01-01 TO 2021-12-31] — 562 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] : 2315
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 1 : 1000 résultats — cumul : 1000/2315
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 2 : 1000 résultats — cumul : 2000/2315
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 3 : 315 résultats — cumul : 2315/2315
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2022-01-01 TO 2022-12-31] — 2315 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] : 3441
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 1 : 1000 résultats — cumul : 1000/3441
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 2 : 1000 résultats — cumul : 2000/3441
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 3 : 1000 résultats — cumul : 3000/3441
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] Page 4 : 441 résultats — cumul : 3441/3441
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2023-01-01 TO 2023-12-31] — 3441 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] : 2253
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 1 : 1000 résultats — cumul : 1000/2253
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 2 : 1000 résultats — cumul : 2000/2253
# code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] Page 3 : 253 résultats — cumul : 2253/2253
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31]
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:D AND date_reception_dpe:[2024-01-01 TO 2024-12-31] — 2253 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:E : 5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 4 : 1000 résultats — cumul : 4000/5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 5 : 1000 résultats — cumul : 5000/5380
# code_postal_ban:69007 AND etiquette_dpe:E Page 6 : 380 résultats — cumul : 5380/5380
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:E — 5380 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:F : 1743
# code_postal_ban:69007 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1743
# code_postal_ban:69007 AND etiquette_dpe:F Page 2 : 743 résultats — cumul : 1743/1743
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:F — 1743 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69007 AND etiquette_dpe:G : 1050
# code_postal_ban:69007 AND etiquette_dpe:G Page 1 : 1000 résultats — cumul : 1000/1050
# code_postal_ban:69007 AND etiquette_dpe:G Page 2 : 50 résultats — cumul : 1050/1050
#  Dernière page atteinte pour code_postal_ban:69007 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69007 AND etiquette_dpe:G — 1050 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 ---
# Total estimé pour code_postal_ban:69005 : 19285
# Nombre trop élevé (19285), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:A : 9
# code_postal_ban:69005 AND etiquette_dpe:A Page 1 : 9 résultats — cumul : 9/9
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:A — 9 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:B : 30
# code_postal_ban:69005 AND etiquette_dpe:B Page 1 : 30 résultats — cumul : 30/30
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:B — 30 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:C : 5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 2 : 1000 résultats — cumul : 2000/5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 3 : 1000 résultats — cumul : 3000/5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 4 : 1000 résultats — cumul : 4000/5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 5 : 1000 résultats — cumul : 5000/5629
# code_postal_ban:69005 AND etiquette_dpe:C Page 6 : 629 résultats — cumul : 5629/5629
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:C
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:C — 5629 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:D : 7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 5 : 1000 résultats — cumul : 5000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 6 : 1000 résultats — cumul : 6000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 7 : 1000 résultats — cumul : 7000/7549
# code_postal_ban:69005 AND etiquette_dpe:D Page 8 : 549 résultats — cumul : 7549/7549
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:D — 7549 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:E : 4005
# code_postal_ban:69005 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/4005
# code_postal_ban:69005 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/4005
# code_postal_ban:69005 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/4005
# code_postal_ban:69005 AND etiquette_dpe:E Page 4 : 1000 résultats — cumul : 4000/4005
# code_postal_ban:69005 AND etiquette_dpe:E Page 5 : 5 résultats — cumul : 4005/4005
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:E — 4005 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:F : 1111
# code_postal_ban:69005 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1111
# code_postal_ban:69005 AND etiquette_dpe:F Page 2 : 111 résultats — cumul : 1111/1111
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:F — 1111 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69005 AND etiquette_dpe:G : 952
# code_postal_ban:69005 AND etiquette_dpe:G Page 1 : 952 résultats — cumul : 952/952
#  Dernière page atteinte pour code_postal_ban:69005 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69005 AND etiquette_dpe:G — 952 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 ---
# Total estimé pour code_postal_ban:69001 : 11341
# Nombre trop élevé (11341), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:A : 1
# code_postal_ban:69001 AND etiquette_dpe:A Page 1 : 1 résultats — cumul : 1/1
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:A — 1 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:B : 11
# code_postal_ban:69001 AND etiquette_dpe:B Page 1 : 11 résultats — cumul : 11/11
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:B — 11 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:C : 1995
# code_postal_ban:69001 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/1995
# code_postal_ban:69001 AND etiquette_dpe:C Page 2 : 995 résultats — cumul : 1995/1995
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:C
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:C — 1995 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:D : 4075
# code_postal_ban:69001 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/4075
# code_postal_ban:69001 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/4075
# code_postal_ban:69001 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/4075
# code_postal_ban:69001 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/4075
# code_postal_ban:69001 AND etiquette_dpe:D Page 5 : 75 résultats — cumul : 4075/4075
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:D — 4075 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:E : 3035
# code_postal_ban:69001 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/3035
# code_postal_ban:69001 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/3035
# code_postal_ban:69001 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/3035
# code_postal_ban:69001 AND etiquette_dpe:E Page 4 : 35 résultats — cumul : 3035/3035
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:E — 3035 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:F : 1342
# code_postal_ban:69001 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1342
# code_postal_ban:69001 AND etiquette_dpe:F Page 2 : 342 résultats — cumul : 1342/1342
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:F — 1342 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69001 AND etiquette_dpe:G : 882
# code_postal_ban:69001 AND etiquette_dpe:G Page 1 : 882 résultats — cumul : 882/882
#  Dernière page atteinte pour code_postal_ban:69001 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69001 AND etiquette_dpe:G — 882 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 ---
# Total estimé pour code_postal_ban:69004 : 10113
# Nombre trop élevé (10113), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:A : 1
# code_postal_ban:69004 AND etiquette_dpe:A Page 1 : 1 résultats — cumul : 1/1
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:A — 1 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:B : 12
# code_postal_ban:69004 AND etiquette_dpe:B Page 1 : 12 résultats — cumul : 12/12
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:B — 12 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:C : 2344
# code_postal_ban:69004 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/2344
# code_postal_ban:69004 AND etiquette_dpe:C Page 2 : 1000 résultats — cumul : 2000/2344
# code_postal_ban:69004 AND etiquette_dpe:C Page 3 : 344 résultats — cumul : 2344/2344
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:C
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:C — 2344 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:D : 3702
# code_postal_ban:69004 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/3702
# code_postal_ban:69004 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/3702
# code_postal_ban:69004 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/3702
# code_postal_ban:69004 AND etiquette_dpe:D Page 4 : 702 résultats — cumul : 3702/3702
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:D — 3702 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:E : 2684
# code_postal_ban:69004 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/2684
# code_postal_ban:69004 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/2684
# code_postal_ban:69004 AND etiquette_dpe:E Page 3 : 684 résultats — cumul : 2684/2684
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:E — 2684 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:F : 839
# code_postal_ban:69004 AND etiquette_dpe:F Page 1 : 839 résultats — cumul : 839/839
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:F — 839 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69004 AND etiquette_dpe:G : 531
# code_postal_ban:69004 AND etiquette_dpe:G Page 1 : 531 résultats — cumul : 531/531
#  Dernière page atteinte pour code_postal_ban:69004 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69004 AND etiquette_dpe:G — 531 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 ---
# Total estimé pour code_postal_ban:69002 : 12916
# Nombre trop élevé (12916), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:A : 11
# code_postal_ban:69002 AND etiquette_dpe:A Page 1 : 11 résultats — cumul : 11/11
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:A — 11 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:B : 422
# code_postal_ban:69002 AND etiquette_dpe:B Page 1 : 422 résultats — cumul : 422/422
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:B — 422 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:C : 3000
# code_postal_ban:69002 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/3000
# code_postal_ban:69002 AND etiquette_dpe:C Page 2 : 1000 résultats — cumul : 2000/3000
# code_postal_ban:69002 AND etiquette_dpe:C Page 3 : 1000 résultats — cumul : 3000/3000
#  Aucun résultat à la page 4, arrêt.
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:C — 3000 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:D : 4451
# code_postal_ban:69002 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/4451
# code_postal_ban:69002 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/4451
# code_postal_ban:69002 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/4451
# code_postal_ban:69002 AND etiquette_dpe:D Page 4 : 1000 résultats — cumul : 4000/4451
# code_postal_ban:69002 AND etiquette_dpe:D Page 5 : 451 résultats — cumul : 4451/4451
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:D — 4451 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:E : 3002
# code_postal_ban:69002 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/3002
# code_postal_ban:69002 AND etiquette_dpe:E Page 2 : 1000 résultats — cumul : 2000/3002
# code_postal_ban:69002 AND etiquette_dpe:E Page 3 : 1000 résultats — cumul : 3000/3002
# code_postal_ban:69002 AND etiquette_dpe:E Page 4 : 2 résultats — cumul : 3002/3002
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:E — 3002 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:F : 1176
# code_postal_ban:69002 AND etiquette_dpe:F Page 1 : 1000 résultats — cumul : 1000/1176
# code_postal_ban:69002 AND etiquette_dpe:F Page 2 : 176 résultats — cumul : 1176/1176
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:F — 1176 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69002 AND etiquette_dpe:G : 854
# code_postal_ban:69002 AND etiquette_dpe:G Page 1 : 854 résultats — cumul : 854/854
#  Dernière page atteinte pour code_postal_ban:69002 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69002 AND etiquette_dpe:G — 854 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 ---
# Total estimé pour code_postal_ban:69003 : 30806
# Nombre trop élevé (30806), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69003 AND etiquette_dpe:A : 10
# code_postal_ban:69003 AND etiquette_dpe:A Page 1 : 10 résultats — cumul : 10/10
#  Dernière page atteinte pour code_postal_ban:69003 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69003 AND etiquette_dpe:A — 10 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69003 AND etiquette_dpe:B : 156
# code_postal_ban:69003 AND etiquette_dpe:B Page 1 : 156 résultats — cumul : 156/156
#  Dernière page atteinte pour code_postal_ban:69003 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69003 AND etiquette_dpe:B — 156 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69003 AND etiquette_dpe:C : 11232
# Nombre trop élevé (11232) pour 69003 et étiquette C, découpage par année...
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] ---
# Total estimé pour code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] : 480
# code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] Page 1 : 480 résultats — cumul : 480/480
#  Dernière page atteinte pour code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31]
# --- Fin téléchargement : code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2021-01-01 TO 2021-12-31] — 480 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] ---
# Total estimé pour code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] : 1453
# code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 1 : 1000 résultats — cumul : 1000/1453
# code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] Page 2 : 453 résultats — cumul : 1453/1453
#  Dernière page atteinte pour code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31]
# --- Fin téléchargement : code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2022-01-01 TO 2022-12-31] — 1453 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 AND etiquette_dpe:C AND date_reception_dpe:[2023-01-01 TO 2023-12-31] ---
# ...
#
#
# --- Début téléchargement : code_postal_ban:69690 ---
# Total estimé pour code_postal_ban:69690 : 644
# code_postal_ban:69690 Page 1 : 644 résultats — cumul : 644/644
#  Dernière page atteinte pour code_postal_ban:69690
# --- Fin téléchargement : code_postal_ban:69690 — 644 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69550 ---
# Total estimé pour code_postal_ban:69550 : 938
# code_postal_ban:69550 Page 1 : 938 résultats — cumul : 938/938
#  Dernière page atteinte pour code_postal_ban:69550
# --- Fin téléchargement : code_postal_ban:69550 — 938 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69650 ---
# Total estimé pour code_postal_ban:69650 : 1049
# code_postal_ban:69650 Page 1 : 1000 résultats — cumul : 1000/1049
# code_postal_ban:69650 Page 2 : 49 résultats — cumul : 1049/1049
#  Dernière page atteinte pour code_postal_ban:69650
# --- Fin téléchargement : code_postal_ban:69650 — 1049 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69830 ---
# Total estimé pour code_postal_ban:69830 : 557
# code_postal_ban:69830 Page 1 : 557 résultats — cumul : 557/557
#  Dernière page atteinte pour code_postal_ban:69830
# --- Fin téléchargement : code_postal_ban:69830 — 557 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69290 ---
# Total estimé pour code_postal_ban:69290 : 4305
# code_postal_ban:69290 Page 1 : 1000 résultats — cumul : 1000/4305
# code_postal_ban:69290 Page 2 : 1000 résultats — cumul : 2000/4305
# code_postal_ban:69290 Page 3 : 1000 résultats — cumul : 3000/4305
# code_postal_ban:69290 Page 4 : 1000 résultats — cumul : 4000/4305
# code_postal_ban:69290 Page 5 : 305 résultats — cumul : 4305/4305
#  Dernière page atteinte pour code_postal_ban:69290
# --- Fin téléchargement : code_postal_ban:69290 — 4305 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69230 ---
# Total estimé pour code_postal_ban:69230 : 3620
# code_postal_ban:69230 Page 1 : 1000 résultats — cumul : 1000/3620
# code_postal_ban:69230 Page 2 : 1000 résultats — cumul : 2000/3620
# code_postal_ban:69230 Page 3 : 1000 résultats — cumul : 3000/3620
# code_postal_ban:69230 Page 4 : 620 résultats — cumul : 3620/3620
#  Dernière page atteinte pour code_postal_ban:69230
# --- Fin téléchargement : code_postal_ban:69230 — 3620 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69610 ---
# Total estimé pour code_postal_ban:69610 : 776
# code_postal_ban:69610 Page 1 : 776 résultats — cumul : 776/776
#  Dernière page atteinte pour code_postal_ban:69610
# --- Fin téléchargement : code_postal_ban:69610 — 776 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69110 ---
# Total estimé pour code_postal_ban:69110 : 3784
# code_postal_ban:69110 Page 1 : 1000 résultats — cumul : 1000/3784
# code_postal_ban:69110 Page 2 : 1000 résultats — cumul : 2000/3784
# code_postal_ban:69110 Page 3 : 1000 résultats — cumul : 3000/3784
# code_postal_ban:69110 Page 4 : 784 résultats — cumul : 3784/3784
#  Dernière page atteinte pour code_postal_ban:69110
# --- Fin téléchargement : code_postal_ban:69110 — 3784 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69190 ---
# Total estimé pour code_postal_ban:69190 : 4615
# code_postal_ban:69190 Page 1 : 1000 résultats — cumul : 1000/4615
# code_postal_ban:69190 Page 2 : 1000 résultats — cumul : 2000/4615
# code_postal_ban:69190 Page 3 : 1000 résultats — cumul : 3000/4615
# code_postal_ban:69190 Page 4 : 1000 résultats — cumul : 4000/4615
# code_postal_ban:69190 Page 5 : 615 résultats — cumul : 4615/4615
#  Dernière page atteinte pour code_postal_ban:69190
# --- Fin téléchargement : code_postal_ban:69190 — 4615 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69450 ---
# Total estimé pour code_postal_ban:69450 : 927
# code_postal_ban:69450 Page 1 : 927 résultats — cumul : 927/927
#  Dernière page atteinte pour code_postal_ban:69450
# --- Fin téléchargement : code_postal_ban:69450 — 927 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69370 ---
# Total estimé pour code_postal_ban:69370 : 980
# code_postal_ban:69370 Page 1 : 980 résultats — cumul : 980/980
#  Dernière page atteinte pour code_postal_ban:69370
# --- Fin téléchargement : code_postal_ban:69370 — 980 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69280 ---
# Total estimé pour code_postal_ban:69280 : 681
# code_postal_ban:69280 Page 1 : 681 résultats — cumul : 681/681
#  Dernière page atteinte pour code_postal_ban:69280
# --- Fin téléchargement : code_postal_ban:69280 — 681 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69470 ---
# Total estimé pour code_postal_ban:69470 : 759
# code_postal_ban:69470 Page 1 : 759 résultats — cumul : 759/759
#  Dernière page atteinte pour code_postal_ban:69470
# --- Fin téléchargement : code_postal_ban:69470 — 759 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69480 ---
# Total estimé pour code_postal_ban:69480 : 2122
# code_postal_ban:69480 Page 1 : 1000 résultats — cumul : 1000/2122
# code_postal_ban:69480 Page 2 : 1000 résultats — cumul : 2000/2122
# code_postal_ban:69480 Page 3 : 122 résultats — cumul : 2122/2122
#  Dernière page atteinte pour code_postal_ban:69480
# --- Fin téléchargement : code_postal_ban:69480 — 2122 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69530 ---
# Total estimé pour code_postal_ban:69530 : 1862
# code_postal_ban:69530 Page 1 : 1000 résultats — cumul : 1000/1862
# code_postal_ban:69530 Page 2 : 862 résultats — cumul : 1862/1862
#  Dernière page atteinte pour code_postal_ban:69530
# --- Fin téléchargement : code_postal_ban:69530 — 1862 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69310 ---
# Total estimé pour code_postal_ban:69310 : 1946
# code_postal_ban:69310 Page 1 : 1000 résultats — cumul : 1000/1946
# code_postal_ban:69310 Page 2 : 946 résultats — cumul : 1946/1946
#  Dernière page atteinte pour code_postal_ban:69310
# --- Fin téléchargement : code_postal_ban:69310 — 1946 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69600 ---
# Total estimé pour code_postal_ban:69600 : 6625
# code_postal_ban:69600 Page 1 : 1000 résultats — cumul : 1000/6625
# code_postal_ban:69600 Page 2 : 1000 résultats — cumul : 2000/6625
# code_postal_ban:69600 Page 3 : 1000 résultats — cumul : 3000/6625
# code_postal_ban:69600 Page 4 : 1000 résultats — cumul : 4000/6625
# code_postal_ban:69600 Page 5 : 1000 résultats — cumul : 5000/6625
# code_postal_ban:69600 Page 6 : 1000 résultats — cumul : 6000/6625
# code_postal_ban:69600 Page 7 : 625 résultats — cumul : 6625/6625
#  Dernière page atteinte pour code_postal_ban:69600
# --- Fin téléchargement : code_postal_ban:69600 — 6625 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69350 ---
# Total estimé pour code_postal_ban:69350 : 1516
# code_postal_ban:69350 Page 1 : 1000 résultats — cumul : 1000/1516
# code_postal_ban:69350 Page 2 : 516 résultats — cumul : 1516/1516
#  Dernière page atteinte pour code_postal_ban:69350
# --- Fin téléchargement : code_postal_ban:69350 — 1516 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69860 ---
# Total estimé pour code_postal_ban:69860 : 221
# code_postal_ban:69860 Page 1 : 221 résultats — cumul : 221/221
#  Dernière page atteinte pour code_postal_ban:69860
# --- Fin téléchargement : code_postal_ban:69860 — 221 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69760 ---
# Total estimé pour code_postal_ban:69760 : 876
# code_postal_ban:69760 Page 1 : 876 résultats — cumul : 876/876
#  Dernière page atteinte pour code_postal_ban:69760
# --- Fin téléchargement : code_postal_ban:69760 — 876 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69840 ---
# Total estimé pour code_postal_ban:69840 : 303
# code_postal_ban:69840 Page 1 : 303 résultats — cumul : 303/303
#  Dernière page atteinte pour code_postal_ban:69840
# --- Fin téléchargement : code_postal_ban:69840 — 303 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69540 ---
# Total estimé pour code_postal_ban:69540 : 1422
# code_postal_ban:69540 Page 1 : 1000 résultats — cumul : 1000/1422
# code_postal_ban:69540 Page 2 : 422 résultats — cumul : 1422/1422
#  Dernière page atteinte pour code_postal_ban:69540
# --- Fin téléchargement : code_postal_ban:69540 — 1422 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69520 ---
# Total estimé pour code_postal_ban:69520 : 1804
# code_postal_ban:69520 Page 1 : 1000 résultats — cumul : 1000/1804
# code_postal_ban:69520 Page 2 : 804 résultats — cumul : 1804/1804
#  Dernière page atteinte pour code_postal_ban:69520
# --- Fin téléchargement : code_postal_ban:69520 — 1804 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69340 ---
# Total estimé pour code_postal_ban:69340 : 2734
# code_postal_ban:69340 Page 1 : 1000 résultats — cumul : 1000/2734
# code_postal_ban:69340 Page 2 : 1000 résultats — cumul : 2000/2734
# code_postal_ban:69340 Page 3 : 734 résultats — cumul : 2734/2734
#  Dernière page atteinte pour code_postal_ban:69340
# --- Fin téléchargement : code_postal_ban:69340 — 2734 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69130 ---
# Total estimé pour code_postal_ban:69130 : 4328
# code_postal_ban:69130 Page 1 : 1000 résultats — cumul : 1000/4328
# code_postal_ban:69130 Page 2 : 1000 résultats — cumul : 2000/4328
# code_postal_ban:69130 Page 3 : 1000 résultats — cumul : 3000/4328
# code_postal_ban:69130 Page 4 : 1000 résultats — cumul : 4000/4328
# code_postal_ban:69130 Page 5 : 328 résultats — cumul : 4328/4328
#  Dernière page atteinte pour code_postal_ban:69130
# --- Fin téléchargement : code_postal_ban:69130 — 4328 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69570 ---
# Total estimé pour code_postal_ban:69570 : 1245
# code_postal_ban:69570 Page 1 : 1000 résultats — cumul : 1000/1245
# code_postal_ban:69570 Page 2 : 245 résultats — cumul : 1245/1245
#  Dernière page atteinte pour code_postal_ban:69570
# --- Fin téléchargement : code_postal_ban:69570 — 1245 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69660 ---
# Total estimé pour code_postal_ban:69660 : 713
# code_postal_ban:69660 Page 1 : 713 résultats — cumul : 713/713
#  Dernière page atteinte pour code_postal_ban:69660
# --- Fin téléchargement : code_postal_ban:69660 — 713 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69115 ---
# Total estimé pour code_postal_ban:69115 : 42
# code_postal_ban:69115 Page 1 : 42 résultats — cumul : 42/42
#  Dernière page atteinte pour code_postal_ban:69115
# --- Fin téléchargement : code_postal_ban:69115 — 42 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69260 ---
# Total estimé pour code_postal_ban:69260 : 836
# code_postal_ban:69260 Page 1 : 836 résultats — cumul : 836/836
#  Dernière page atteinte pour code_postal_ban:69260
# --- Fin téléchargement : code_postal_ban:69260 — 836 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69410 ---
# Total estimé pour code_postal_ban:69410 : 1646
# code_postal_ban:69410 Page 1 : 1000 résultats — cumul : 1000/1646
# code_postal_ban:69410 Page 2 : 646 résultats — cumul : 1646/1646
#  Dernière page atteinte pour code_postal_ban:69410
# --- Fin téléchargement : code_postal_ban:69410 — 1646 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69630 ---
# Total estimé pour code_postal_ban:69630 : 1072
# code_postal_ban:69630 Page 1 : 1000 résultats — cumul : 1000/1072
# code_postal_ban:69630 Page 2 : 72 résultats — cumul : 1072/1072
#  Dernière page atteinte pour code_postal_ban:69630
# --- Fin téléchargement : code_postal_ban:69630 — 1072 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 ---
# Total estimé pour code_postal_ban:69300 : 10445
# Nombre trop élevé (10445), découpage par étiquette...
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:A ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:A : 10
# code_postal_ban:69300 AND etiquette_dpe:A Page 1 : 10 résultats — cumul : 10/10
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:A
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:A — 10 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:B ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:B : 400
# code_postal_ban:69300 AND etiquette_dpe:B Page 1 : 400 résultats — cumul : 400/400
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:B
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:B — 400 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:C ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:C : 3734
# code_postal_ban:69300 AND etiquette_dpe:C Page 1 : 1000 résultats — cumul : 1000/3734
# code_postal_ban:69300 AND etiquette_dpe:C Page 2 : 1000 résultats — cumul : 2000/3734
# code_postal_ban:69300 AND etiquette_dpe:C Page 3 : 1000 résultats — cumul : 3000/3734
# code_postal_ban:69300 AND etiquette_dpe:C Page 4 : 734 résultats — cumul : 3734/3734
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:C
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:C — 3734 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:D ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:D : 3728
# code_postal_ban:69300 AND etiquette_dpe:D Page 1 : 1000 résultats — cumul : 1000/3728
# code_postal_ban:69300 AND etiquette_dpe:D Page 2 : 1000 résultats — cumul : 2000/3728
# code_postal_ban:69300 AND etiquette_dpe:D Page 3 : 1000 résultats — cumul : 3000/3728
# code_postal_ban:69300 AND etiquette_dpe:D Page 4 : 728 résultats — cumul : 3728/3728
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:D
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:D — 3728 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:E ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:E : 1770
# code_postal_ban:69300 AND etiquette_dpe:E Page 1 : 1000 résultats — cumul : 1000/1770
# code_postal_ban:69300 AND etiquette_dpe:E Page 2 : 770 résultats — cumul : 1770/1770
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:E
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:E — 1770 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:F ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:F : 519
# code_postal_ban:69300 AND etiquette_dpe:F Page 1 : 519 résultats — cumul : 519/519
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:F
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:F — 519 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 AND etiquette_dpe:G ---
# Total estimé pour code_postal_ban:69300 AND etiquette_dpe:G : 284
# code_postal_ban:69300 AND etiquette_dpe:G Page 1 : 284 résultats — cumul : 284/284
#  Dernière page atteinte pour code_postal_ban:69300 AND etiquette_dpe:G
# --- Fin téléchargement : code_postal_ban:69300 AND etiquette_dpe:G — 284 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69500 ---
# Total estimé pour code_postal_ban:69500 : 8129
# code_postal_ban:69500 Page 1 : 1000 résultats — cumul : 1000/8129
# code_postal_ban:69500 Page 2 : 1000 résultats — cumul : 2000/8129
# code_postal_ban:69500 Page 3 : 1000 résultats — cumul : 3000/8129
# code_postal_ban:69500 Page 4 : 1000 résultats — cumul : 4000/8129
# code_postal_ban:69500 Page 5 : 1000 résultats — cumul : 5000/8129
# code_postal_ban:69500 Page 6 : 1000 résultats — cumul : 6000/8129
# code_postal_ban:69500 Page 7 : 1000 résultats — cumul : 7000/8129
# code_postal_ban:69500 Page 8 : 1000 résultats — cumul : 8000/8129
# code_postal_ban:69500 Page 9 : 129 résultats — cumul : 8129/8129
#  Dernière page atteinte pour code_postal_ban:69500
# --- Fin téléchargement : code_postal_ban:69500 — 8129 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69126 ---
# Total estimé pour code_postal_ban:69126 : 703
# code_postal_ban:69126 Page 1 : 703 résultats — cumul : 703/703
#  Dernière page atteinte pour code_postal_ban:69126
# --- Fin téléchargement : code_postal_ban:69126 — 703 DPE récupérés ---
#
# Export terminé : data_existants_69.csv (407945 lignes)

# %%
data_existants = pd.read_csv("data_existants_69.csv")
data_existants.shape
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_4856\1118627378.py:1: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_existants = pd.read_csv("data_existants_69.csv")
# (407945, 145)

# %%
data_existants['date_reception_dpe'].sort_values().unique()
# Out:
# array(['2021-07-01', '2021-07-02', '2021-07-03', ..., '2025-10-11',
#        '2025-10-12', '2025-10-13'], shape=(1565,), dtype=object)

# %%
data_existants.head()
# Out:
#              configuration_installation_chauffage_n1  \
# 0                   Installation de chauffage simple
# 1                   Installation de chauffage simple
# 2  Installation de chauffage avec en appoint un i...
# 3                                                NaN
# 4                   Installation de chauffage simple
#
#    conso_chauffage_installation_chauffage_n1  \
# 0                                    23676.5
# 1                                    24049.0
# 2                                        1.0
# 3                                        NaN
# 4                                        1.0
#
#                            type_generateur_n1_ecs_n1  score_ban  \
# 0        Chaudière fioul basse température 1991-2015       0.36
# 1  Ballon électrique à accumulation vertical Autr...       0.25
# 2  Ballon électrique à accumulation vertical Caté...       0.27
# 3                                                NaN       0.27
# 4  Ballon électrique à accumulation vertical Autr...       0.41
#
#    conso_auxiliaires_ep  deperditions_murs  cout_eclairage  \
# 0                2136.4               80.0            66.4
# 1                 882.8              135.0            33.9
# 2                   1.0              148.6            15.3
# 3                1734.7               50.7            63.1
# 4                 866.1              169.3            48.8
#
#    conso_auxiliaires_ef                  statut_geocodage  \
# 0                 928.9  adresse géocodée ban à l'adresse
# 1                 383.8  adresse géocodée ban à l'adresse
# 2                   0.0  adresse géocodée ban à l'adresse
# 3                 754.2  adresse géocodée ban à l'adresse
# 4                 376.6  adresse géocodée ban à l'adresse
#
#    ventilation_posterieure_2012  ...  emission_ges_auxiliaires  \
# 0                             0  ...                      59.4
# 1                             0  ...                      24.6
# 2                             0  ...                       0.0
# 3                             0  ...                      48.3
# 4                             0  ...                      24.1
#
#    usage_generateur_n1_ecs_n1 _score      categorie_enr  numero_voie_ban  \
# 0             chauffage + ecs    NaN                NaN              NaN
# 1                         ecs    NaN  chauffage au bois              NaN
# 2                   chauffage    NaN  chauffage au bois              290
# 3                         NaN    NaN    pompe à chaleur              NaN
# 4                   chauffage    NaN                NaN             2101
#
#              nom_rue_ban type_installation_chauffage  type_installation_ecs  \
# 0                    NaN                         NaN                    NaN
# 1                    NaN                         NaN                    NaN
# 2       Chemin du Vernay                         NaN                    NaN
# 3                    NaN                         NaN                    NaN
# 4  Route du Saint-Rigaud                         NaN                    NaN
#
#    nombre_appartement  surface_habitable_immeuble
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
#
# [5 rows x 145 columns]

# %%
data_existants['annee_construction'].sort_values().unique()
# Out:
# array([1460., 1516., 1522., 1525., 1550., 1580., 1595., 1600., 1610.,
#        1621., 1622., 1640., 1650., 1656., 1657., 1660., 1663., 1675.,
#        1681., 1686., 1690., 1700., 1720., 1731., 1732., 1740., 1741.,
#        1750., 1751., 1760., 1765., 1770., 1779., 1780., 1783., 1785.,
#        1789., 1790., 1793., 1800., 1802., 1810., 1812., 1815., 1820.,
#        1822., 1824., 1825., 1827., 1830., 1832., 1835., 1836., 1840.,
#        1842., 1845., 1846., 1848., 1849., 1850., 1853., 1855., 1856.,
#        1858., 1860., 1861., 1862., 1863., 1864., 1865., 1867., 1868.,
#        1869., 1870., 1871., 1872., 1873., 1875., 1876., 1878., 1880.,
#        1882., 1883., 1884., 1885., 1886., 1887., 1888., 1889., 1890.,
#        1891., 1892., 1893., 1894., 1895., 1896., 1897., 1898., 1899.,
#        1900., 1901., 1902., 1903., 1904., 1905., 1906., 1907., 1908.,
#        1909., 1910., 1911., 1912., 1913., 1914., 1915., 1916., 1917.,
#        1918., 1919., 1920., 1921., 1922., 1923., 1924., 1925., 1926.,
#        1927., 1928., 1929., 1930., 1931., 1932., 1933., 1934., 1935.,
#        1936., 1937., 1938., 1939., 1940., 1941., 1942., 1943., 1944.,
#        1945., 1946., 1947., 1948., 1949., 1950., 1951., 1952., 1953.,
#        1954., 1955., 1956., 1957., 1958., 1959., 1960., 1961., 1962.,
#        1963., 1964., 1965., 1966., 1967., 1968., 1969., 1970., 1971.,
#        1972., 1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980.,
#        1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989.,
#        1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998.,
#        1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007.,
#        2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022., 2023., 2024., 2025.,
#          nan])

# %%
data_existants.loc[data_existants['annee_construction'] > 2015, 'annee_construction'] \
    .value_counts().sort_index()
# Out:
# annee_construction
# 2016.0    3007
# 2017.0    2253
# 2018.0    2557
# 2019.0    1894
# 2020.0    1450
# 2021.0    1801
# 2022.0     335
# 2023.0     341
# 2024.0      92
# 2025.0      92
# Name: count, dtype: int64

# %%
data_existants['annee_construction'].sort_values().unique()
# Out:
# array([1460., 1516., 1522., 1525., 1550., 1580., 1595., 1600., 1610.,
#        1621., 1622., 1640., 1650., 1656., 1657., 1660., 1663., 1675.,
#        1681., 1686., 1690., 1700., 1720., 1731., 1732., 1740., 1741.,
#        1750., 1751., 1760., 1765., 1770., 1779., 1780., 1783., 1785.,
#        1789., 1790., 1793., 1800., 1802., 1810., 1812., 1815., 1820.,
#        1822., 1824., 1825., 1827., 1830., 1832., 1835., 1836., 1840.,
#        1842., 1845., 1846., 1848., 1849., 1850., 1853., 1855., 1856.,
#        1858., 1860., 1861., 1862., 1863., 1864., 1865., 1867., 1868.,
#        1869., 1870., 1871., 1872., 1873., 1875., 1876., 1878., 1880.,
#        1882., 1883., 1884., 1885., 1886., 1887., 1888., 1889., 1890.,
#        1891., 1892., 1893., 1894., 1895., 1896., 1897., 1898., 1899.,
#        1900., 1901., 1902., 1903., 1904., 1905., 1906., 1907., 1908.,
#        1909., 1910., 1911., 1912., 1913., 1914., 1915., 1916., 1917.,
#        1918., 1919., 1920., 1921., 1922., 1923., 1924., 1925., 1926.,
#        1927., 1928., 1929., 1930., 1931., 1932., 1933., 1934., 1935.,
#        1936., 1937., 1938., 1939., 1940., 1941., 1942., 1943., 1944.,
#        1945., 1946., 1947., 1948., 1949., 1950., 1951., 1952., 1953.,
#        1954., 1955., 1956., 1957., 1958., 1959., 1960., 1961., 1962.,
#        1963., 1964., 1965., 1966., 1967., 1968., 1969., 1970., 1971.,
#        1972., 1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980.,
#        1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989.,
#        1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998.,
#        1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007.,
#        2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022., 2023., 2024., 2025.,
#          nan])

# %% [markdown]
# ## 2-  données des logements neufs

# %%
# recuperation des noms de variables des logements neufs
import json
#data = json.loads('variables.json')
file = 'variables_logement_neufs.json'
with open(file) as train_file:
    data = json.load(train_file)
variables = pd.json_normalize(data['results'])
res = list(variables.columns.values)
colonnes = ",".join(res)
colonnes
# Out:
# 'emission_ges_5_usages_energie_n1,appartement_non_visite,score_ban,emission_ges_5_usages_par_m2,surface_habitable_immeuble,conso_auxiliaires_ep,complement_adresse_logement,cout_eclairage,cout_auxiliaires,conso_auxiliaires_ef,statut_geocodage,ventilation_posterieure_2012,cout_chauffage,conso_5_usages_par_m2_ep,emission_ges_refroidissement,date_etablissement_dpe,conso_ecs_ef_energie_n1,hauteur_sous_plafond,conso_chauffage_ef,emission_ges_chauffage,nom_commune_ban,conso_5_usages_par_m2_ef,_geopoint,date_visite_diagnostiqueur,type_batiment,conso_chauffage_ef_energie_n1,qualite_isolation_menuiseries,conso_ecs_ep,date_reception_dpe,cout_total_5_usages_energie_n1,cout_ecs_energie_n1,qualite_isolation_plancher_bas,conso_ecs_ef,emission_ges_5_usages,date_derniere_modification_dpe,etiquette_ges,identifiant_ban,modele_dpe,qualite_isolation_enveloppe,ubat_w_par_m2_k,type_energie_n1,emission_ges_eclairage,nom_commune_brut,code_postal_ban,etiquette_dpe,emission_ges_ecs,conso_5_usages_ef,conso_5_usages_ef_energie_n1,code_departement_ban,code_insee_ban,nombre_niveau_immeuble,conso_5_usages_ep,date_fin_validite_dpe,methode_application_dpe,adresse_brut,code_region_ban,cout_total_5_usages,categorie_enr,conso_refroidissement_ef,conso_eclairage_ef,emission_ges_ecs_energie_n1,cout_refroidissement,conso_chauffage_ep,version_dpe,conso_eclairage_ep,nom_rue_ban,coordonnee_cartographique_x_ban,qualite_isolation_murs,conso_refroidissement_ep,type_energie_principale_chauffage,numero_dpe,_i,type_energie_principale_ecs,emission_ges_chauffage_energie_n1,adresse_ban,nombre_appartement,cout_chauffage_energie_n1,_rand,coordonnee_cartographique_y_ban,code_postal_brut,production_electricite_pv_kwhep_par_an,emission_ges_auxiliaires,nombre_niveau_logement,surface_habitable_logement,cout_ecs,_score,_id'

# %%
import requests
import pandas as pd
import concurrent.futures
import os
import time

# === CONFIG ===
BASE_URL = "https://data.ademe.fr/data-fair/api/v1/datasets/dpe02neuf/lines"
CODES_POSTAUX_FILE = "adresses-69.csv"   # fichier contenant une colonne "code_postal"
OUTPUT_FILE = "data_neufs_69.csv"

# Charger les codes postaux du département
code_postaux_df = pd.read_csv(CODES_POSTAUX_FILE, dtype=str, sep=';')
code_postals = code_postaux_df['code_postal'].unique().tolist()

# Colonnes à extraire
listeColumn = "emission_ges_5_usages_energie_n1,appartement_non_visite,score_ban,emission_ges_5_usages_par_m2,surface_habitable_immeuble,conso_auxiliaires_ep,complement_adresse_logement,cout_eclairage," \
"cout_auxiliaires,conso_auxiliaires_ef,statut_geocodage,ventilation_posterieure_2012,cout_chauffage,conso_5_usages_par_m2_ep,emission_ges_refroidissement,date_etablissement_dpe,conso_ecs_ef_energie_n1," \
"hauteur_sous_plafond,conso_chauffage_ef,emission_ges_chauffage,nom_commune_ban,conso_5_usages_par_m2_ef,_geopoint,date_visite_diagnostiqueur,type_batiment,conso_chauffage_ef_energie_n1,qualite_isolation_menuiseries," \
"conso_ecs_ep,date_reception_dpe,cout_total_5_usages_energie_n1,cout_ecs_energie_n1,qualite_isolation_plancher_bas,conso_ecs_ef,emission_ges_5_usages,date_derniere_modification_dpe,etiquette_ges,identifiant_ban,modele_dpe," \
"qualite_isolation_enveloppe,ubat_w_par_m2_k,type_energie_n1,emission_ges_eclairage,nom_commune_brut,code_postal_ban,etiquette_dpe,emission_ges_ecs,conso_5_usages_ef,conso_5_usages_ef_energie_n1,code_departement_ban,code_insee_ban," \
"nombre_niveau_immeuble,conso_5_usages_ep,date_fin_validite_dpe,methode_application_dpe,adresse_brut,code_region_ban,cout_total_5_usages,categorie_enr,conso_refroidissement_ef,conso_eclairage_ef,emission_ges_ecs_energie_n1,cout_refroidissement," \
"conso_chauffage_ep,version_dpe,conso_eclairage_ep,nom_rue_ban,coordonnee_cartographique_x_ban,qualite_isolation_murs,conso_refroidissement_ep,type_energie_principale_chauffage,numero_dpe,_i,type_energie_principale_ecs,emission_ges_chauffage_energie_n1," \
"adresse_ban,nombre_appartement,cout_chauffage_energie_n1,_rand,coordonnee_cartographique_y_ban,code_postal_brut,production_electricite_pv_kwhep_par_an,emission_ges_auxiliaires,nombre_niveau_logement,surface_habitable_logement,cout_ecs"

# Supprimer ancien fichier s'il existe
if os.path.exists(OUTPUT_FILE):
    os.remove(OUTPUT_FILE)

all_results = []

def fetch_data_smart(code_postal, etiquette=None, start_date=None, end_date=None):
    results = []
    size = 1000
    page = 1

    # Construction du filtre q
    q_parts = [f"code_postal_ban:{code_postal}"]
    if etiquette:
        q_parts.append(f"etiquette_dpe:{etiquette}")
    if start_date and end_date:
        q_parts.append(f"date_reception_dpe:[{start_date} TO {end_date}]")
    q_filter = " AND ".join(q_parts)

    print(f"\n--- Début téléchargement : {q_filter} ---")

    # Première requête pour connaître le total
    params = {"page": 1, "size": size, "qs": q_filter, "select": listeColumn, "q_fields": "code_postal_ban,etiquette_dpe,date_reception_dpe"}
    response = requests.get(BASE_URL, params=params)
    if response.status_code != 200:
        print(f" Erreur {response.status_code} pour {q_filter}")
        return results

    data = response.json()
    total = data.get("total", 0)
    print(f"Total estimé pour {q_filter} : {total}")

    # Si total > 1000 et pas encore filtré par etiquette
    if total > 10000 and etiquette is None:
        print(f"Nombre trop élevé ({total}), découpage par étiquette...")
        etiquettes = ["A", "B", "C", "D", "E", "F", "G"]
        for etiq in etiquettes:
            results.extend(fetch_data_smart(code_postal, etiquette=etiq))
        return results

    # Si total > 1000 et déjà filtré par etiquette mais pas par date
    if total > 10000 and etiquette is not None and start_date is None:
        print(f"Nombre trop élevé ({total}) pour {code_postal} et étiquette {etiquette}, découpage par année...")
        for year in range(2021, 2025):  # exemple années 2021 à 2024
            year_start = f"{year}-01-01"
            year_end = f"{year}-12-31"
            results.extend(fetch_data_smart(code_postal, etiquette, year_start, year_end))
        return results

    # Sinon récupération normale par page
    while True:
        params["page"] = page
        response = requests.get(BASE_URL, params=params)
        if response.status_code != 200:
            print(f" Erreur {response.status_code} page {page} pour {q_filter}")
            break

        page_results = response.json().get("results", [])
        if not page_results:
            print(f" Aucun résultat à la page {page}, arrêt.")
            break

        results.extend(page_results)
        print(f"{q_filter} Page {page} : {len(page_results)} résultats — cumul : {len(results)}/{total}")

        if len(page_results) < size:
            print(f" Dernière page atteinte pour {q_filter}")
            break

        page += 1
        time.sleep(3)

    print(f"--- Fin téléchargement : {q_filter} — {len(results)} DPE récupérés ---\n")
    return results

all_results = []
for cp in code_postals:
    all_results.extend(fetch_data_smart(cp))

df = pd.DataFrame(all_results)
df.to_csv("data_neufs_69.csv", index=False, encoding='utf-8')
print(f"Export terminé : data_neufs_69.csv ({len(df)} lignes)")
# Out:
# --- Début téléchargement : code_postal_ban:69790 ---
# Total estimé pour code_postal_ban:69790 : 1
# code_postal_ban:69790 Page 1 : 1 résultats — cumul : 1/1
#  Dernière page atteinte pour code_postal_ban:69790
# --- Fin téléchargement : code_postal_ban:69790 — 1 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69170 ---
# Total estimé pour code_postal_ban:69170 : 233
# code_postal_ban:69170 Page 1 : 233 résultats — cumul : 233/233
#  Dernière page atteinte pour code_postal_ban:69170
# --- Fin téléchargement : code_postal_ban:69170 — 233 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69250 ---
# Total estimé pour code_postal_ban:69250 : 482
# code_postal_ban:69250 Page 1 : 482 résultats — cumul : 482/482
#  Dernière page atteinte pour code_postal_ban:69250
# --- Fin téléchargement : code_postal_ban:69250 — 482 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69380 ---
# Total estimé pour code_postal_ban:69380 : 560
# code_postal_ban:69380 Page 1 : 560 résultats — cumul : 560/560
#  Dernière page atteinte pour code_postal_ban:69380
# --- Fin téléchargement : code_postal_ban:69380 — 560 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69009 ---
# Total estimé pour code_postal_ban:69009 : 1363
# code_postal_ban:69009 Page 1 : 1000 résultats — cumul : 1000/1363
# code_postal_ban:69009 Page 2 : 363 résultats — cumul : 1363/1363
#  Dernière page atteinte pour code_postal_ban:69009
# --- Fin téléchargement : code_postal_ban:69009 — 1363 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69008 ---
# Total estimé pour code_postal_ban:69008 : 3201
# code_postal_ban:69008 Page 1 : 1000 résultats — cumul : 1000/3201
# code_postal_ban:69008 Page 2 : 1000 résultats — cumul : 2000/3201
# code_postal_ban:69008 Page 3 : 1000 résultats — cumul : 3000/3201
# code_postal_ban:69008 Page 4 : 201 résultats — cumul : 3201/3201
#  Dernière page atteinte pour code_postal_ban:69008
# --- Fin téléchargement : code_postal_ban:69008 — 3201 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69006 ---
# Total estimé pour code_postal_ban:69006 : 323
# code_postal_ban:69006 Page 1 : 323 résultats — cumul : 323/323
#  Dernière page atteinte pour code_postal_ban:69006
# --- Fin téléchargement : code_postal_ban:69006 — 323 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69007 ---
# Total estimé pour code_postal_ban:69007 : 2446
# code_postal_ban:69007 Page 1 : 1000 résultats — cumul : 1000/2446
# code_postal_ban:69007 Page 2 : 1000 résultats — cumul : 2000/2446
# code_postal_ban:69007 Page 3 : 446 résultats — cumul : 2446/2446
#  Dernière page atteinte pour code_postal_ban:69007
# --- Fin téléchargement : code_postal_ban:69007 — 2446 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69005 ---
# Total estimé pour code_postal_ban:69005 : 477
# code_postal_ban:69005 Page 1 : 477 résultats — cumul : 477/477
#  Dernière page atteinte pour code_postal_ban:69005
# --- Fin téléchargement : code_postal_ban:69005 — 477 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69001 ---
# Total estimé pour code_postal_ban:69001 : 44
# code_postal_ban:69001 Page 1 : 44 résultats — cumul : 44/44
#  Dernière page atteinte pour code_postal_ban:69001
# --- Fin téléchargement : code_postal_ban:69001 — 44 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69004 ---
# Total estimé pour code_postal_ban:69004 : 223
# code_postal_ban:69004 Page 1 : 223 résultats — cumul : 223/223
#  Dernière page atteinte pour code_postal_ban:69004
# --- Fin téléchargement : code_postal_ban:69004 — 223 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69002 ---
# Total estimé pour code_postal_ban:69002 : 378
# code_postal_ban:69002 Page 1 : 378 résultats — cumul : 378/378
#  Dernière page atteinte pour code_postal_ban:69002
# --- Fin téléchargement : code_postal_ban:69002 — 378 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69003 ---
# Total estimé pour code_postal_ban:69003 : 1042
# code_postal_ban:69003 Page 1 : 1000 résultats — cumul : 1000/1042
# code_postal_ban:69003 Page 2 : 42 résultats — cumul : 1042/1042
#  Dernière page atteinte pour code_postal_ban:69003
# --- Fin téléchargement : code_postal_ban:69003 — 1042 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69780 ---
# Total estimé pour code_postal_ban:69780 : 354
# code_postal_ban:69780 Page 1 : 354 résultats — cumul : 354/354
#  Dernière page atteinte pour code_postal_ban:69780
# --- Fin téléchargement : code_postal_ban:69780 — 354 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69360 ---
# Total estimé pour code_postal_ban:69360 : 515
# code_postal_ban:69360 Page 1 : 515 résultats — cumul : 515/515
#  Dernière page atteinte pour code_postal_ban:69360
# --- Fin téléchargement : code_postal_ban:69360 — 515 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69124 ---
# Total estimé pour code_postal_ban:69124 : 92
# code_postal_ban:69124 Page 1 : 92 résultats — cumul : 92/92
#  Dernière page atteinte pour code_postal_ban:69124
# --- Fin téléchargement : code_postal_ban:69124 — 92 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69580 ---
# Total estimé pour code_postal_ban:69580 : 286
# code_postal_ban:69580 Page 1 : 286 résultats — cumul : 286/286
#  Dernière page atteinte pour code_postal_ban:69580
# --- Fin téléchargement : code_postal_ban:69580 — 286 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69720 ---
# Total estimé pour code_postal_ban:69720 : 438
# code_postal_ban:69720 Page 1 : 438 résultats — cumul : 438/438
#  Dernière page atteinte pour code_postal_ban:69720
# --- Fin téléchargement : code_postal_ban:69720 — 438 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69960 ---
# Total estimé pour code_postal_ban:69960 : 254
# code_postal_ban:69960 Page 1 : 254 résultats — cumul : 254/254
#  Dernière page atteinte pour code_postal_ban:69960
# --- Fin téléchargement : code_postal_ban:69960 — 254 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69320 ---
# Total estimé pour code_postal_ban:69320 : 243
# code_postal_ban:69320 Page 1 : 243 résultats — cumul : 243/243
#  Dernière page atteinte pour code_postal_ban:69320
# --- Fin téléchargement : code_postal_ban:69320 — 243 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69800 ---
# Total estimé pour code_postal_ban:69800 : 1141
# code_postal_ban:69800 Page 1 : 1000 résultats — cumul : 1000/1141
# code_postal_ban:69800 Page 2 : 141 résultats — cumul : 1141/1141
#  Dernière page atteinte pour code_postal_ban:69800
# --- Fin téléchargement : code_postal_ban:69800 — 1141 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69140 ---
# Total estimé pour code_postal_ban:69140 : 874
# code_postal_ban:69140 Page 1 : 874 résultats — cumul : 874/874
#  Dernière page atteinte pour code_postal_ban:69140
# --- Fin téléchargement : code_postal_ban:69140 — 874 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69330 ---
# Total estimé pour code_postal_ban:69330 : 370
# code_postal_ban:69330 Page 1 : 370 résultats — cumul : 370/370
#  Dernière page atteinte pour code_postal_ban:69330
# --- Fin téléchargement : code_postal_ban:69330 — 370 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69970 ---
# Total estimé pour code_postal_ban:69970 : 270
# code_postal_ban:69970 Page 1 : 270 résultats — cumul : 270/270
#  Dernière page atteinte pour code_postal_ban:69970
# --- Fin téléchargement : code_postal_ban:69970 — 270 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69730 ---
# Total estimé pour code_postal_ban:69730 : 45
# code_postal_ban:69730 Page 1 : 45 résultats — cumul : 45/45
#  Dernière page atteinte pour code_postal_ban:69730
# --- Fin téléchargement : code_postal_ban:69730 — 45 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69740 ---
# Total estimé pour code_postal_ban:69740 : 208
# code_postal_ban:69740 Page 1 : 208 résultats — cumul : 208/208
#  Dernière page atteinte pour code_postal_ban:69740
# --- Fin téléchargement : code_postal_ban:69740 — 208 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69150 ---
# Total estimé pour code_postal_ban:69150 : 670
# code_postal_ban:69150 Page 1 : 670 résultats — cumul : 670/670
#  Dernière page atteinte pour code_postal_ban:69150
# --- Fin téléchargement : code_postal_ban:69150 — 670 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69680 ---
# Total estimé pour code_postal_ban:69680 : 219
# code_postal_ban:69680 Page 1 : 219 résultats — cumul : 219/219
#  Dernière page atteinte pour code_postal_ban:69680
# --- Fin téléchargement : code_postal_ban:69680 — 219 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69510 ---
# Total estimé pour code_postal_ban:69510 : 355
# code_postal_ban:69510 Page 1 : 355 résultats — cumul : 355/355
#  Dernière page atteinte pour code_postal_ban:69510
# --- Fin téléchargement : code_postal_ban:69510 — 355 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69390 ---
# Total estimé pour code_postal_ban:69390 : 311
# code_postal_ban:69390 Page 1 : 311 résultats — cumul : 311/311
#  Dernière page atteinte pour code_postal_ban:69390
# --- Fin téléchargement : code_postal_ban:69390 — 311 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69910 ---
# Total estimé pour code_postal_ban:69910 : 18
# code_postal_ban:69910 Page 1 : 18 résultats — cumul : 18/18
#  Dernière page atteinte pour code_postal_ban:69910
# --- Fin téléchargement : code_postal_ban:69910 — 18 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69100 ---
# Total estimé pour code_postal_ban:69100 : 3776
# code_postal_ban:69100 Page 1 : 1000 résultats — cumul : 1000/3776
# code_postal_ban:69100 Page 2 : 1000 résultats — cumul : 2000/3776
# code_postal_ban:69100 Page 3 : 1000 résultats — cumul : 3000/3776
# code_postal_ban:69100 Page 4 : 776 résultats — cumul : 3776/3776
#  Dernière page atteinte pour code_postal_ban:69100
# --- Fin téléchargement : code_postal_ban:69100 — 3776 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69640 ---
# Total estimé pour code_postal_ban:69640 : 61
# code_postal_ban:69640 Page 1 : 61 résultats — cumul : 61/61
#  Dernière page atteinte pour code_postal_ban:69640
# --- Fin téléchargement : code_postal_ban:69640 — 61 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69770 ---
# Total estimé pour code_postal_ban:69770 : 28
# code_postal_ban:69770 Page 1 : 28 résultats — cumul : 28/28
#  Dernière page atteinte pour code_postal_ban:69770
# --- Fin téléchargement : code_postal_ban:69770 — 28 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69400 ---
# Total estimé pour code_postal_ban:69400 : 2100
# code_postal_ban:69400 Page 1 : 1000 résultats — cumul : 1000/2100
# code_postal_ban:69400 Page 2 : 1000 résultats — cumul : 2000/2100
# code_postal_ban:69400 Page 3 : 100 résultats — cumul : 2100/2100
#  Dernière page atteinte pour code_postal_ban:69400
# --- Fin téléchargement : code_postal_ban:69400 — 2100 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69430 ---
# Total estimé pour code_postal_ban:69430 : 57
# code_postal_ban:69430 Page 1 : 57 résultats — cumul : 57/57
#  Dernière page atteinte pour code_postal_ban:69430
# --- Fin téléchargement : code_postal_ban:69430 — 57 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69820 ---
# Total estimé pour code_postal_ban:69820 : 32
# code_postal_ban:69820 Page 1 : 32 résultats — cumul : 32/32
#  Dernière page atteinte pour code_postal_ban:69820
# --- Fin téléchargement : code_postal_ban:69820 — 32 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69460 ---
# Total estimé pour code_postal_ban:69460 : 65
# code_postal_ban:69460 Page 1 : 65 résultats — cumul : 65/65
#  Dernière page atteinte pour code_postal_ban:69460
# --- Fin téléchargement : code_postal_ban:69460 — 65 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69200 ---
# Total estimé pour code_postal_ban:69200 : 1884
# code_postal_ban:69200 Page 1 : 1000 résultats — cumul : 1000/1884
# code_postal_ban:69200 Page 2 : 884 résultats — cumul : 1884/1884
#  Dernière page atteinte pour code_postal_ban:69200
# --- Fin téléchargement : code_postal_ban:69200 — 1884 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69120 ---
# Total estimé pour code_postal_ban:69120 : 1791
# code_postal_ban:69120 Page 1 : 1000 résultats — cumul : 1000/1791
# code_postal_ban:69120 Page 2 : 791 résultats — cumul : 1791/1791
#  Dernière page atteinte pour code_postal_ban:69120
# --- Fin téléchargement : code_postal_ban:69120 — 1791 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69420 ---
# Total estimé pour code_postal_ban:69420 : 190
# code_postal_ban:69420 Page 1 : 190 résultats — cumul : 190/190
#  Dernière page atteinte pour code_postal_ban:69420
# --- Fin téléchargement : code_postal_ban:69420 — 190 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69670 ---
# Total estimé pour code_postal_ban:69670 : 157
# code_postal_ban:69670 Page 1 : 157 résultats — cumul : 157/157
#  Dernière page atteinte pour code_postal_ban:69670
# --- Fin téléchargement : code_postal_ban:69670 — 157 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69890 ---
# Total estimé pour code_postal_ban:69890 : 148
# code_postal_ban:69890 Page 1 : 148 résultats — cumul : 148/148
#  Dernière page atteinte pour code_postal_ban:69890
# --- Fin téléchargement : code_postal_ban:69890 — 148 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69620 ---
# Total estimé pour code_postal_ban:69620 : 99
# code_postal_ban:69620 Page 1 : 99 résultats — cumul : 99/99
#  Dernière page atteinte pour code_postal_ban:69620
# --- Fin téléchargement : code_postal_ban:69620 — 99 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69240 ---
# Total estimé pour code_postal_ban:69240 : 8
# code_postal_ban:69240 Page 1 : 8 résultats — cumul : 8/8
#  Dernière page atteinte pour code_postal_ban:69240
# --- Fin téléchargement : code_postal_ban:69240 — 8 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69160 ---
# Total estimé pour code_postal_ban:69160 : 618
# code_postal_ban:69160 Page 1 : 618 résultats — cumul : 618/618
#  Dernière page atteinte pour code_postal_ban:69160
# --- Fin téléchargement : code_postal_ban:69160 — 618 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69220 ---
# Total estimé pour code_postal_ban:69220 : 227
# code_postal_ban:69220 Page 1 : 227 résultats — cumul : 227/227
#  Dernière page atteinte pour code_postal_ban:69220
# --- Fin téléchargement : code_postal_ban:69220 — 227 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69440 ---
# Total estimé pour code_postal_ban:69440 : 257
# code_postal_ban:69440 Page 1 : 257 résultats — cumul : 257/257
#  Dernière page atteinte pour code_postal_ban:69440
# --- Fin téléchargement : code_postal_ban:69440 — 257 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69490 ---
# Total estimé pour code_postal_ban:69490 : 204
# code_postal_ban:69490 Page 1 : 204 résultats — cumul : 204/204
#  Dernière page atteinte pour code_postal_ban:69490
# --- Fin téléchargement : code_postal_ban:69490 — 204 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69700 ---
# Total estimé pour code_postal_ban:69700 : 714
# code_postal_ban:69700 Page 1 : 714 résultats — cumul : 714/714
#  Dernière page atteinte pour code_postal_ban:69700
# --- Fin téléchargement : code_postal_ban:69700 — 714 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69560 ---
# Total estimé pour code_postal_ban:69560 : 114
# code_postal_ban:69560 Page 1 : 114 résultats — cumul : 114/114
#  Dernière page atteinte pour code_postal_ban:69560
# --- Fin téléchargement : code_postal_ban:69560 — 114 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69590 ---
# Total estimé pour code_postal_ban:69590 : 51
# code_postal_ban:69590 Page 1 : 51 résultats — cumul : 51/51
#  Dernière page atteinte pour code_postal_ban:69590
# --- Fin téléchargement : code_postal_ban:69590 — 51 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69270 ---
# Total estimé pour code_postal_ban:69270 : 289
# code_postal_ban:69270 Page 1 : 289 résultats — cumul : 289/289
#  Dernière page atteinte pour code_postal_ban:69270
# --- Fin téléchargement : code_postal_ban:69270 — 289 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69870 ---
# Total estimé pour code_postal_ban:69870 : 25
# code_postal_ban:69870 Page 1 : 25 résultats — cumul : 25/25
#  Dernière page atteinte pour code_postal_ban:69870
# --- Fin téléchargement : code_postal_ban:69870 — 25 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69210 ---
# Total estimé pour code_postal_ban:69210 : 463
# code_postal_ban:69210 Page 1 : 463 résultats — cumul : 463/463
#  Dernière page atteinte pour code_postal_ban:69210
# --- Fin téléchargement : code_postal_ban:69210 — 463 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69850 ---
# Total estimé pour code_postal_ban:69850 : 103
# code_postal_ban:69850 Page 1 : 103 résultats — cumul : 103/103
#  Dernière page atteinte pour code_postal_ban:69850
# --- Fin téléchargement : code_postal_ban:69850 — 103 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69930 ---
# Total estimé pour code_postal_ban:69930 : 34
# code_postal_ban:69930 Page 1 : 34 résultats — cumul : 34/34
#  Dernière page atteinte pour code_postal_ban:69930
# --- Fin téléchargement : code_postal_ban:69930 — 34 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69690 ---
# Total estimé pour code_postal_ban:69690 : 14
# code_postal_ban:69690 Page 1 : 14 résultats — cumul : 14/14
#  Dernière page atteinte pour code_postal_ban:69690
# --- Fin téléchargement : code_postal_ban:69690 — 14 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69550 ---
# Total estimé pour code_postal_ban:69550 : 96
# code_postal_ban:69550 Page 1 : 96 résultats — cumul : 96/96
#  Dernière page atteinte pour code_postal_ban:69550
# --- Fin téléchargement : code_postal_ban:69550 — 96 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69650 ---
# Total estimé pour code_postal_ban:69650 : 250
# code_postal_ban:69650 Page 1 : 250 résultats — cumul : 250/250
#  Dernière page atteinte pour code_postal_ban:69650
# --- Fin téléchargement : code_postal_ban:69650 — 250 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69830 ---
# Total estimé pour code_postal_ban:69830 : 168
# code_postal_ban:69830 Page 1 : 168 résultats — cumul : 168/168
#  Dernière page atteinte pour code_postal_ban:69830
# --- Fin téléchargement : code_postal_ban:69830 — 168 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69290 ---
# Total estimé pour code_postal_ban:69290 : 607
# code_postal_ban:69290 Page 1 : 607 résultats — cumul : 607/607
#  Dernière page atteinte pour code_postal_ban:69290
# --- Fin téléchargement : code_postal_ban:69290 — 607 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69230 ---
# Total estimé pour code_postal_ban:69230 : 67
# code_postal_ban:69230 Page 1 : 67 résultats — cumul : 67/67
#  Dernière page atteinte pour code_postal_ban:69230
# --- Fin téléchargement : code_postal_ban:69230 — 67 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69610 ---
# Total estimé pour code_postal_ban:69610 : 79
# code_postal_ban:69610 Page 1 : 79 résultats — cumul : 79/79
#  Dernière page atteinte pour code_postal_ban:69610
# --- Fin téléchargement : code_postal_ban:69610 — 79 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69110 ---
# Total estimé pour code_postal_ban:69110 : 415
# code_postal_ban:69110 Page 1 : 415 résultats — cumul : 415/415
#  Dernière page atteinte pour code_postal_ban:69110
# --- Fin téléchargement : code_postal_ban:69110 — 415 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69190 ---
# Total estimé pour code_postal_ban:69190 : 278
# code_postal_ban:69190 Page 1 : 278 résultats — cumul : 278/278
#  Dernière page atteinte pour code_postal_ban:69190
# --- Fin téléchargement : code_postal_ban:69190 — 278 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69450 ---
# Total estimé pour code_postal_ban:69450 : 329
# code_postal_ban:69450 Page 1 : 329 résultats — cumul : 329/329
#  Dernière page atteinte pour code_postal_ban:69450
# --- Fin téléchargement : code_postal_ban:69450 — 329 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69370 ---
# Total estimé pour code_postal_ban:69370 : 150
# code_postal_ban:69370 Page 1 : 150 résultats — cumul : 150/150
#  Dernière page atteinte pour code_postal_ban:69370
# --- Fin téléchargement : code_postal_ban:69370 — 150 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69280 ---
# Total estimé pour code_postal_ban:69280 : 138
# code_postal_ban:69280 Page 1 : 138 résultats — cumul : 138/138
#  Dernière page atteinte pour code_postal_ban:69280
# --- Fin téléchargement : code_postal_ban:69280 — 138 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69470 ---
# Total estimé pour code_postal_ban:69470 : 8
# code_postal_ban:69470 Page 1 : 8 résultats — cumul : 8/8
#  Dernière page atteinte pour code_postal_ban:69470
# --- Fin téléchargement : code_postal_ban:69470 — 8 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69480 ---
# Total estimé pour code_postal_ban:69480 : 331
# code_postal_ban:69480 Page 1 : 331 résultats — cumul : 331/331
#  Dernière page atteinte pour code_postal_ban:69480
# --- Fin téléchargement : code_postal_ban:69480 — 331 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69530 ---
# Total estimé pour code_postal_ban:69530 : 634
# code_postal_ban:69530 Page 1 : 634 résultats — cumul : 634/634
#  Dernière page atteinte pour code_postal_ban:69530
# --- Fin téléchargement : code_postal_ban:69530 — 634 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69310 ---
# Total estimé pour code_postal_ban:69310 : 177
# code_postal_ban:69310 Page 1 : 177 résultats — cumul : 177/177
#  Dernière page atteinte pour code_postal_ban:69310
# --- Fin téléchargement : code_postal_ban:69310 — 177 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69600 ---
# Total estimé pour code_postal_ban:69600 : 147
# code_postal_ban:69600 Page 1 : 147 résultats — cumul : 147/147
#  Dernière page atteinte pour code_postal_ban:69600
# --- Fin téléchargement : code_postal_ban:69600 — 147 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69350 ---
# Total estimé pour code_postal_ban:69350 : 2
# code_postal_ban:69350 Page 1 : 2 résultats — cumul : 2/2
#  Dernière page atteinte pour code_postal_ban:69350
# --- Fin téléchargement : code_postal_ban:69350 — 2 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69860 ---
# Total estimé pour code_postal_ban:69860 : 11
# code_postal_ban:69860 Page 1 : 11 résultats — cumul : 11/11
#  Dernière page atteinte pour code_postal_ban:69860
# --- Fin téléchargement : code_postal_ban:69860 — 11 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69760 ---
# Total estimé pour code_postal_ban:69760 : 162
# code_postal_ban:69760 Page 1 : 162 résultats — cumul : 162/162
#  Dernière page atteinte pour code_postal_ban:69760
# --- Fin téléchargement : code_postal_ban:69760 — 162 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69840 ---
# Total estimé pour code_postal_ban:69840 : 18
# code_postal_ban:69840 Page 1 : 18 résultats — cumul : 18/18
#  Dernière page atteinte pour code_postal_ban:69840
# --- Fin téléchargement : code_postal_ban:69840 — 18 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69540 ---
# Total estimé pour code_postal_ban:69540 : 460
# code_postal_ban:69540 Page 1 : 460 résultats — cumul : 460/460
#  Dernière page atteinte pour code_postal_ban:69540
# --- Fin téléchargement : code_postal_ban:69540 — 460 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69520 ---
# Total estimé pour code_postal_ban:69520 : 177
# code_postal_ban:69520 Page 1 : 177 résultats — cumul : 177/177
#  Dernière page atteinte pour code_postal_ban:69520
# --- Fin téléchargement : code_postal_ban:69520 — 177 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69340 ---
# Total estimé pour code_postal_ban:69340 : 518
# code_postal_ban:69340 Page 1 : 518 résultats — cumul : 518/518
#  Dernière page atteinte pour code_postal_ban:69340
# --- Fin téléchargement : code_postal_ban:69340 — 518 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69130 ---
# Total estimé pour code_postal_ban:69130 : 223
# code_postal_ban:69130 Page 1 : 223 résultats — cumul : 223/223
#  Dernière page atteinte pour code_postal_ban:69130
# --- Fin téléchargement : code_postal_ban:69130 — 223 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69570 ---
# Total estimé pour code_postal_ban:69570 : 231
# code_postal_ban:69570 Page 1 : 231 résultats — cumul : 231/231
#  Dernière page atteinte pour code_postal_ban:69570
# --- Fin téléchargement : code_postal_ban:69570 — 231 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69660 ---
# Total estimé pour code_postal_ban:69660 : 370
# code_postal_ban:69660 Page 1 : 370 résultats — cumul : 370/370
#  Dernière page atteinte pour code_postal_ban:69660
# --- Fin téléchargement : code_postal_ban:69660 — 370 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69115 ---
# Total estimé pour code_postal_ban:69115 : 8
# code_postal_ban:69115 Page 1 : 8 résultats — cumul : 8/8
#  Dernière page atteinte pour code_postal_ban:69115
# --- Fin téléchargement : code_postal_ban:69115 — 8 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69260 ---
# Total estimé pour code_postal_ban:69260 : 167
# code_postal_ban:69260 Page 1 : 167 résultats — cumul : 167/167
#  Dernière page atteinte pour code_postal_ban:69260
# --- Fin téléchargement : code_postal_ban:69260 — 167 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69410 ---
# Total estimé pour code_postal_ban:69410 : 344
# code_postal_ban:69410 Page 1 : 344 résultats — cumul : 344/344
#  Dernière page atteinte pour code_postal_ban:69410
# --- Fin téléchargement : code_postal_ban:69410 — 344 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69630 ---
# Total estimé pour code_postal_ban:69630 : 257
# code_postal_ban:69630 Page 1 : 257 résultats — cumul : 257/257
#  Dernière page atteinte pour code_postal_ban:69630
# --- Fin téléchargement : code_postal_ban:69630 — 257 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69300 ---
# Total estimé pour code_postal_ban:69300 : 671
# code_postal_ban:69300 Page 1 : 671 résultats — cumul : 671/671
#  Dernière page atteinte pour code_postal_ban:69300
# --- Fin téléchargement : code_postal_ban:69300 — 671 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69500 ---
# Total estimé pour code_postal_ban:69500 : 1559
# code_postal_ban:69500 Page 1 : 1000 résultats — cumul : 1000/1559
# code_postal_ban:69500 Page 2 : 559 résultats — cumul : 1559/1559
#  Dernière page atteinte pour code_postal_ban:69500
# --- Fin téléchargement : code_postal_ban:69500 — 1559 DPE récupérés ---
#
#
# --- Début téléchargement : code_postal_ban:69126 ---
# Total estimé pour code_postal_ban:69126 : 108
# code_postal_ban:69126 Page 1 : 108 résultats — cumul : 108/108
#  Dernière page atteinte pour code_postal_ban:69126
# --- Fin téléchargement : code_postal_ban:69126 — 108 DPE récupérés ---
#
# Export terminé : data_neufs_69.csv (40105 lignes)

# %%
data_neufs = pd.read_csv("data_neufs_69.csv")
data_neufs.head()
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_4856\2118894399.py:1: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_neufs = pd.read_csv("data_neufs_69.csv")
#    emission_ges_5_usages_energie_n1  appartement_non_visite  score_ban  \
# 0                              27.5                     0.0       0.22
# 1                            1251.7                     NaN       0.96
# 2                            1181.5                     NaN       0.96
# 3                              29.6                     0.0       0.62
# 4                            1122.7                     NaN       0.96
#
#    emission_ges_5_usages_par_m2  surface_habitable_immeuble  \
# 0                           1.7                       116.6
# 1                          18.9                         NaN
# 2                          20.4                         NaN
# 3                           2.2                       144.1
# 4                          22.1                         NaN
#
#    conso_auxiliaires_ep                     complement_adresse_logement  \
# 0                 163.3  1-Mr et Mme SIMON Florian et Pauline-1-LogZone
# 1                  20.9                                             NaN
# 2                  20.9                                             NaN
# 3                 121.0                        1-Batiment n 1-1-LogZone
# 4                  20.9                                             NaN
#
#    cout_eclairage  cout_auxiliaires  conso_auxiliaires_ef  ...  \
# 0            45.0              14.0                  71.0  ...
# 1           132.9               3.3                   9.1  ...
# 2           115.4               3.3                   9.1  ...
# 3            54.0               9.0                  52.6  ...
# 4           101.2               3.3                   9.1  ...
#
#   cout_chauffage_energie_n1   _rand  coordonnee_cartographique_y_ban  \
# 0                     350.0  794968                       6569539.78
# 1                     374.4  124952                       6533498.54
# 2                     371.6  242969                       6533498.54
# 3                     562.0  255810                       6542759.44
# 4                     328.8  165190                       6533498.54
#
#    code_postal_brut  production_electricite_pv_kwhep_par_an  \
# 0             78490                                     0.0
# 1             69170                                     0.0
# 2             69170                                     0.0
# 3             69170                                     0.0
# 4             69170                                     0.0
#
#   emission_ges_auxiliaires  nombre_niveau_logement  \
# 0                      4.5                     1.0
# 1                      0.6                     1.0
# 2                      0.6                     1.0
# 3                      3.4                     1.0
# 4                      0.6                     1.0
#
#    surface_habitable_logement  cout_ecs  _score
# 0                       116.6      95.0     NaN
# 1                        67.8     415.7     NaN
# 2                        59.0     392.8     NaN
# 3                       144.1     133.0     NaN
# 4                        51.7     403.1     NaN
#
# [5 rows x 86 columns]

# %%
data_neufs['date_reception_dpe'].sort_values().unique()
# Out:
# array(['2021-07-01', '2021-07-05', '2021-07-09', ..., '2025-10-16',
#        '2025-10-17', '2025-10-20'], shape=(1137,), dtype=object)

# %% [markdown]
# ## III- Manipulation des données de l'ademe

# %%
# variables des logements anciens
for col in data_existants.columns:
    print(col)
# Out:
# configuration_installation_chauffage_n1
# conso_chauffage_installation_chauffage_n1
# type_generateur_n1_ecs_n1
# score_ban
# conso_auxiliaires_ep
# deperditions_murs
# cout_eclairage
# conso_auxiliaires_ef
# statut_geocodage
# ventilation_posterieure_2012
# cout_chauffage
# conso_5_usages_par_m2_ep
# date_etablissement_dpe
# conso_ecs_ef_energie_n1
# conso_ecs_ef_energie_n2
# emission_ges_chauffage
# description_installation_chauffage_n1
# conso_5_usages_par_m2_ef
# cout_ecs_energie_n2
# conso_chauffage_ef_energie_n1
# conso_chauffage_ef_energie_n2
# qualite_isolation_menuiseries
# cout_total_5_usages_energie_n2
# date_reception_dpe
# cout_total_5_usages_energie_n1
# cout_ecs_energie_n1
# qualite_isolation_plancher_bas
# modele_dpe
# qualite_isolation_enveloppe
# conso_chauffage_generateur_n1_installation_n1
# type_energie_n1
# emission_ges_eclairage
# type_energie_n2
# code_postal_ban
# emission_ges_ecs
# conso_5_usages_ef_energie_n2
# conso_5_usages_ef
# conso_5_usages_ef_energie_n1
# code_insee_ban
# deperditions_planchers_bas
# conso_5_usages_ep
# date_fin_validite_dpe
# deperditions_enveloppe
# code_region_ban
# volume_stockage_generateur_n1_ecs_n1
# surface_chauffee_installation_chauffage_n1
# version_dpe
# besoin_ecs
# coordonnee_cartographique_x_ban
# type_generateur_chauffage_principal
# type_energie_principale_ecs
# apport_solaire_saison_chauffe
# adresse_ban
# deperditions_renouvellement_air
# _rand
# surface_habitable_desservie_par_installation_ecs_n1
# production_electricite_pv_kwhep_par_an
# nombre_niveau_logement
# surface_habitable_logement
# cout_ecs
# type_installation_ecs_n1
# emission_ges_5_usages_energie_n1
# emission_ges_5_usages_energie_n2
# apport_interne_saison_froide
# emission_ges_5_usages_par_m2
# description_generateur_chauffage_n1_installation_n1
# qualite_isolation_plancher_haut_comble_perdu
# apport_interne_saison_chauffe
# apport_solaire_saison_froide
# type_generateur_n1_installation_n1
# nombre_logements_desservis_par_installation_ecs_n1
# complement_adresse_logement
# cout_auxiliaires
# type_emetteur_installation_chauffage_n1
# besoin_chauffage
# configuration_installation_ecs_n1
# description_installation_ecs_n1
# classe_inertie_batiment
# deperditions_ponts_thermiques
# type_generateur_chauffage_principal_ecs
# emission_ges_refroidissement
# hauteur_sous_plafond
# conso_chauffage_ef
# nom_commune_ban
# annee_construction
# _geopoint
# date_visite_diagnostiqueur
# type_batiment
# periode_construction
# conso_ecs_ep
# conso_ecs_ef
# emission_ges_5_usages
# date_derniere_modification_dpe
# etiquette_ges
# identifiant_ban
# deperditions_baies_vitrees
# type_energie_generateur_n1_ecs_n1
# ubat_w_par_m2_k
# numero_etage_appartement
# nom_commune_brut
# conso_ef_installation_ecs_n1
# etiquette_dpe
# description_generateur_n1_ecs_n1
# code_departement_ban
# type_installation_chauffage_n1
# methode_application_dpe
# adresse_brut
# cout_total_5_usages
# conso_refroidissement_ef
# conso_eclairage_ef
# deperditions_planchers_hauts
# zone_climatique
# conso_ef_generateur_n1_ecs_n1
# emission_ges_ecs_energie_n1
# emission_ges_ecs_energie_n2
# cout_refroidissement
# conso_chauffage_ep
# conso_eclairage_ep
# usage_generateur_n1_installation_n1
# qualite_isolation_murs
# type_installation_solaire_n1
# classe_altitude
# conso_refroidissement_ep
# type_energie_principale_chauffage
# numero_dpe
# _i
# besoin_refroidissement
# emission_ges_chauffage_energie_n2
# emission_ges_chauffage_energie_n1
# cout_chauffage_energie_n2
# deperditions_portes
# cout_chauffage_energie_n1
# coordonnee_cartographique_y_ban
# type_energie_generateur_n1_installation_n1
# code_postal_brut
# emission_ges_auxiliaires
# usage_generateur_n1_ecs_n1
# _score
# categorie_enr
# numero_voie_ban
# nom_rue_ban
# type_installation_chauffage
# type_installation_ecs
# nombre_appartement
# surface_habitable_immeuble

# %%
# variables des logements neufs
for col in data_neufs.columns:
    print(col)
# Out:
# emission_ges_5_usages_energie_n1
# appartement_non_visite
# score_ban
# emission_ges_5_usages_par_m2
# surface_habitable_immeuble
# conso_auxiliaires_ep
# complement_adresse_logement
# cout_eclairage
# cout_auxiliaires
# conso_auxiliaires_ef
# statut_geocodage
# ventilation_posterieure_2012
# cout_chauffage
# conso_5_usages_par_m2_ep
# emission_ges_refroidissement
# date_etablissement_dpe
# conso_ecs_ef_energie_n1
# hauteur_sous_plafond
# conso_chauffage_ef
# emission_ges_chauffage
# nom_commune_ban
# conso_5_usages_par_m2_ef
# _geopoint
# date_visite_diagnostiqueur
# type_batiment
# conso_chauffage_ef_energie_n1
# qualite_isolation_menuiseries
# conso_ecs_ep
# date_reception_dpe
# cout_total_5_usages_energie_n1
# cout_ecs_energie_n1
# qualite_isolation_plancher_bas
# conso_ecs_ef
# emission_ges_5_usages
# date_derniere_modification_dpe
# etiquette_ges
# identifiant_ban
# modele_dpe
# qualite_isolation_enveloppe
# ubat_w_par_m2_k
# type_energie_n1
# emission_ges_eclairage
# nom_commune_brut
# code_postal_ban
# etiquette_dpe
# emission_ges_ecs
# conso_5_usages_ef
# conso_5_usages_ef_energie_n1
# code_departement_ban
# code_insee_ban
# nombre_niveau_immeuble
# conso_5_usages_ep
# date_fin_validite_dpe
# methode_application_dpe
# adresse_brut
# code_region_ban
# cout_total_5_usages
# categorie_enr
# conso_refroidissement_ef
# conso_eclairage_ef
# emission_ges_ecs_energie_n1
# cout_refroidissement
# conso_chauffage_ep
# version_dpe
# conso_eclairage_ep
# nom_rue_ban
# coordonnee_cartographique_x_ban
# qualite_isolation_murs
# conso_refroidissement_ep
# type_energie_principale_chauffage
# numero_dpe
# _i
# type_energie_principale_ecs
# emission_ges_chauffage_energie_n1
# adresse_ban
# nombre_appartement
# cout_chauffage_energie_n1
# _rand
# coordonnee_cartographique_y_ban
# code_postal_brut
# production_electricite_pv_kwhep_par_an
# emission_ges_auxiliaires
# nombre_niveau_logement
# surface_habitable_logement
# cout_ecs
# _score

# %%
# proportions des valeurs manquantes
missing_summary = (
    data_existants.isna().mean() * 100
).reset_index()

missing_summary.columns = ['variable', 'pct_missing']
missing_summary = missing_summary[missing_summary['pct_missing'] > 0]
missing_summary = missing_summary.sort_values('pct_missing', ascending=False)
print(missing_summary)
# Out:
#                                          variable  pct_missing
# 137                                        _score   100.000000
# 138                                 categorie_enr    76.063685
# 144                    surface_habitable_immeuble    48.023631
# 66   qualite_isolation_plancher_haut_comble_perdu    45.564230
# 84                             annee_construction    42.469941
# ..                                            ...          ...
# 82                             conso_chauffage_ef     0.001471
# 116                            conso_chauffage_ep     0.001471
# 106                                  adresse_brut     0.000981
# 7                            conso_auxiliaires_ef     0.000245
# 97                                ubat_w_par_m2_k     0.000245
#
# [102 rows x 2 columns]

# %%
# proportions des valeurs manquantes
missing_summary = (
    data_neufs.isna().mean() * 100
).reset_index()

missing_summary.columns = ['variable', 'pct_missing']
missing_summary = missing_summary[missing_summary['pct_missing'] > 0]
missing_summary = missing_summary.sort_values('pct_missing', ascending=False)
print(missing_summary)
# Out:
#                           variable  pct_missing
# 85                          _score   100.000000
# 57                   categorie_enr    63.059469
# 6      complement_adresse_logement    26.560279
# 82          nombre_niveau_logement    20.004987
# 4       surface_habitable_immeuble     8.704650
# 50          nombre_niveau_immeuble     8.348086
# 75              nombre_appartement     5.101608
# 65                     nom_rue_ban     4.655280
# 1           appartement_non_visite     4.228899
# 83      surface_habitable_logement     1.007356
# 31  qualite_isolation_plancher_bas     0.087271
# 55                 code_region_ban     0.039895
# 48            code_departement_ban     0.039895
# 54                    adresse_brut     0.012467
# 42                nom_commune_brut     0.002493

# %%
# verification des valeurs manquantes sur les adresses des logements neufs
data_neufs['adresse_ban'].isna().sum()
# Out:
# np.int64(0)

# %%
data_existants['adresse_ban'].value_counts(dropna=True)
# Out:
# adresse_ban
# 173 Avenue Barthélémy Buyer 69005 Lyon      1527
# 134 Rue Challemel Lacour 69008 Lyon          978
# 44 Rue de Champvert 69005 Lyon               975
# 241 Avenue du Plateau 69009 Lyon             935
# 3 Avenue de Ménival 69005 Lyon               772
#                                             ...
# 34 Chemin de la Vigneronne 69126 Brindas       1
# 44 Chemin du Guillermy 69126 Brindas           1
# 258 Chemin des Andres 69126 Brindas            1
# 63 Rue du Vieux Bourg 69126 Brindas            1
# 147 Route du Pont du Chene 69126 Brindas       1
# Name: count, Length: 83797, dtype: int64

# %%
# verification des valeurs manquantes sur les adresses des logements existants
data_existants['adresse_ban'].isna().sum()
# Out:
# np.int64(564)

# %%
pct_missing_address = data_existants['adresse_ban'].isna().mean() * 100
print(f"{pct_missing_address:.2f}% des lignes ont une adresse manquante")
# Out:
# 0.14% des lignes ont une adresse manquante

# %%
mask_adresse_na = data_existants['adresse_ban'].isna()

# Pourcentage de valeurs manquantes dans les autres colonnes parmi ces lignes
cols_a_verifier = ['code_postal_ban', 'nom_commune_ban', 'code_insee_ban']

for col in cols_a_verifier:
    pct_missing = data_existants.loc[mask_adresse_na, col].isna().mean() * 100
    print(f"{col}: {pct_missing:.2f}% manquant parmi les lignes sans adresse")
# Out:
# code_postal_ban: 0.00% manquant parmi les lignes sans adresse
# nom_commune_ban: 0.00% manquant parmi les lignes sans adresse
# code_insee_ban: 0.00% manquant parmi les lignes sans adresse

# %%
data_existants.loc[
    mask_adresse_na & (
        data_existants['code_postal_ban'].notna() |
        data_existants['nom_commune_ban'].notna() |
        data_existants['code_insee_ban'].notna()
    ),
    ['adresse_ban', 'code_postal_ban', 'nom_commune_ban', 'code_insee_ban', 'etiquette_dpe']
]
# Out:
#        adresse_ban  code_postal_ban     nom_commune_ban code_insee_ban  \
# 3212           NaN            69250  FLEURIEU-SUR-SAÔNE          69085
# 3216           NaN            69250  Curis-au-Mont-d'Or          69071
# 3219           NaN            69250  Neuville-sur-Sa?ne          69143
# 3255           NaN            69250  CURIS-AU-MONT-D'OR          69071
# 6457           NaN            69380           DOMMARTIN          69076
# ...            ...              ...                 ...            ...
# 398330         NaN            69300    CALUIRE ET CUIRE          69034
# 399189         NaN            69500                BRON          69029
# 399196         NaN            69500                BRON          69029
# 399210         NaN            69500                BRON          69029
# 399231         NaN            69500                BRON          69029
#
#        etiquette_dpe
# 3212               C
# 3216               D
# 3219               C
# 3255               D
# 6457               A
# ...              ...
# 398330             F
# 399189             D
# 399196             D
# 399210             D
# 399231             C
#
# [564 rows x 5 columns]

# %% [markdown]
# etant données que nous avons un taux bas de valeurs manquantes pour les adresses des logements nous allons les supprimer

# %%
data_existants = data_existants.dropna(subset=['adresse_ban']).reset_index(drop=True)

# %%
data_existants['adresse_ban'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### uniformisation des données des deux dataframes

# %%
# selection des colonnes communes aux deux dataframes
# Colonnes des deux dataframes
import pandas as pd
cols_existants = set(data_existants.columns)
cols_neufs = set(data_neufs.columns)

# Colonnes qui matchent
colonnes_communes = data_existants.columns.intersection(data_neufs.columns).tolist()
print("Colonnes communes :", colonnes_communes)

# Nombre de colonnes communes
nb_colonnes_communes = len(colonnes_communes)
print("Nombre de colonnes communes :", nb_colonnes_communes)
# Out:
# Colonnes communes : ['score_ban', 'conso_auxiliaires_ep', 'cout_eclairage', 'conso_auxiliaires_ef', 'statut_geocodage', 'ventilation_posterieure_2012', 'cout_chauffage', 'conso_5_usages_par_m2_ep', 'date_etablissement_dpe', 'conso_ecs_ef_energie_n1', 'emission_ges_chauffage', 'conso_5_usages_par_m2_ef', 'conso_chauffage_ef_energie_n1', 'qualite_isolation_menuiseries', 'date_reception_dpe', 'cout_total_5_usages_energie_n1', 'cout_ecs_energie_n1', 'qualite_isolation_plancher_bas', 'modele_dpe', 'qualite_isolation_enveloppe', 'type_energie_n1', 'emission_ges_eclairage', 'code_postal_ban', 'emission_ges_ecs', 'conso_5_usages_ef', 'conso_5_usages_ef_energie_n1', 'code_insee_ban', 'conso_5_usages_ep', 'date_fin_validite_dpe', 'code_region_ban', 'version_dpe', 'coordonnee_cartographique_x_ban', 'type_energie_principale_ecs', 'adresse_ban', '_rand', 'production_electricite_pv_kwhep_par_an', 'nombre_niveau_logement', 'surface_habitable_logement', 'cout_ecs', 'emission_ges_5_usages_energie_n1', 'emission_ges_5_usages_par_m2', 'complement_adresse_logement', 'cout_auxiliaires', 'emission_ges_refroidissement', 'hauteur_sous_plafond', 'conso_chauffage_ef', 'nom_commune_ban', '_geopoint', 'date_visite_diagnostiqueur', 'type_batiment', 'conso_ecs_ep', 'conso_ecs_ef', 'emission_ges_5_usages', 'date_derniere_modification_dpe', 'etiquette_ges', 'identifiant_ban', 'ubat_w_par_m2_k', 'nom_commune_brut', 'etiquette_dpe', 'code_departement_ban', 'methode_application_dpe', 'adresse_brut', 'cout_total_5_usages', 'conso_refroidissement_ef', 'conso_eclairage_ef', 'emission_ges_ecs_energie_n1', 'cout_refroidissement', 'conso_chauffage_ep', 'conso_eclairage_ep', 'qualite_isolation_murs', 'conso_refroidissement_ep', 'type_energie_principale_chauffage', 'numero_dpe', '_i', 'emission_ges_chauffage_energie_n1', 'cout_chauffage_energie_n1', 'coordonnee_cartographique_y_ban', 'code_postal_brut', 'emission_ges_auxiliaires', '_score', 'categorie_enr', 'nom_rue_ban', 'nombre_appartement', 'surface_habitable_immeuble']
# Nombre de colonnes communes : 84

# %%
# Colonnes à garder pour chaque dataframe
colonnes_existants = colonnes_communes.copy()
if "annee_construction" in data_existants.columns and "annee_construction" not in colonnes_existants:
    colonnes_existants.append("annee_construction")

# Sélectionner ces colonnes
data_existants_sel = data_existants[colonnes_existants]
data_neufs_sel = data_neufs[colonnes_communes]

# Harmoniser les colonnes avant concat (important)
data_neufs_sel = data_neufs_sel.reindex(columns=colonnes_existants, fill_value=pd.NA)

# Concaténer les deux
data_ademe = pd.concat([data_existants_sel, data_neufs_sel], ignore_index=True)

print(f"\n DataFrame combiné : {data_ademe.shape[0]:,} lignes et {data_ademe.shape[1]} colonnes")
print("Aperçu :")
print(data_ademe.head())
# Out:
#  DataFrame combiné : 447,486 lignes et 85 colonnes
# Aperçu :
#    score_ban  conso_auxiliaires_ep  cout_eclairage  conso_auxiliaires_ef  \
# 0       0.36                2136.4            66.4                 928.9
# 1       0.25                 882.8            33.9                 383.8
# 2       0.27                   1.0            15.3                   0.0
# 3       0.27                1734.7            63.1                 754.2
# 4       0.41                 866.1            48.8                 376.6
#
#                    statut_geocodage  ventilation_posterieure_2012  \
# 0  adresse géocodée ban à l'adresse                             0
# 1  adresse géocodée ban à l'adresse                             0
# 2  adresse géocodée ban à l'adresse                             0
# 3  adresse géocodée ban à l'adresse                             0
# 4  adresse géocodée ban à l'adresse                             0
#
#    cout_chauffage  conso_5_usages_par_m2_ep date_etablissement_dpe  \
# 0          2164.5                     215.0             2022-05-13
# 1          2297.8                     504.0             2022-01-17
# 2          2384.4                     836.0             2021-11-23
# 3          1338.6                     118.0             2021-08-20
# 4          4588.1                     421.0             2021-11-29
#
#    conso_ecs_ef_energie_n1  ...  cout_chauffage_energie_n1  \
# 0                   2343.4  ...                     2164.5
# 1                      0.0  ...                      769.8
# 2                   1339.8  ...                     2384.4
# 3                    916.6  ...                     1338.6
# 4                   2170.8  ...                     4588.1
#
#    coordonnee_cartographique_y_ban  code_postal_brut emission_ges_auxiliaires  \
# 0                       6570836.70             69790                     59.4
# 1                       6566988.16             69790                     24.6
# 2                       6575160.49             69790                      0.0
# 3                       6576616.26             69790                     48.3
# 4                       6567556.10             69790                     24.1
#
#   _score      categorie_enr            nom_rue_ban nombre_appartement  \
# 0    NaN                NaN                    NaN                NaN
# 1    NaN  chauffage au bois                    NaN                NaN
# 2    NaN  chauffage au bois       Chemin du Vernay                NaN
# 3    NaN    pompe à chaleur                    NaN                NaN
# 4    NaN                NaN  Route du Saint-Rigaud                NaN
#
#   surface_habitable_immeuble annee_construction
# 0                        NaN             1994.0
# 1                        NaN             1947.0
# 2                        NaN             1947.0
# 3                        NaN             1947.0
# 4                        NaN             1947.0
#
# [5 rows x 85 columns]
# C:\Users\Surface\AppData\Local\Temp\ipykernel_1988\4004963243.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_ademe = pd.concat([data_existants_sel, data_neufs_sel], ignore_index=True)

# %%
data_ademe['annee_construction'].sort_values().unique()
# Out:
# array([1460., 1516., 1522., 1525., 1550., 1580., 1595., 1600., 1610.,
#        1621., 1622., 1640., 1650., 1656., 1657., 1660., 1663., 1675.,
#        1681., 1686., 1690., 1700., 1720., 1731., 1732., 1740., 1741.,
#        1750., 1751., 1760., 1765., 1770., 1779., 1780., 1783., 1785.,
#        1789., 1790., 1793., 1800., 1802., 1810., 1812., 1815., 1820.,
#        1822., 1824., 1825., 1827., 1830., 1832., 1835., 1836., 1840.,
#        1842., 1845., 1846., 1848., 1849., 1850., 1853., 1855., 1856.,
#        1858., 1860., 1861., 1862., 1863., 1864., 1865., 1867., 1868.,
#        1869., 1870., 1871., 1872., 1873., 1875., 1876., 1878., 1880.,
#        1882., 1883., 1884., 1885., 1886., 1887., 1888., 1889., 1890.,
#        1891., 1892., 1893., 1894., 1895., 1896., 1897., 1898., 1899.,
#        1900., 1901., 1902., 1903., 1904., 1905., 1906., 1907., 1908.,
#        1909., 1910., 1911., 1912., 1913., 1914., 1915., 1916., 1917.,
#        1918., 1919., 1920., 1921., 1922., 1923., 1924., 1925., 1926.,
#        1927., 1928., 1929., 1930., 1931., 1932., 1933., 1934., 1935.,
#        1936., 1937., 1938., 1939., 1940., 1941., 1942., 1943., 1944.,
#        1945., 1946., 1947., 1948., 1949., 1950., 1951., 1952., 1953.,
#        1954., 1955., 1956., 1957., 1958., 1959., 1960., 1961., 1962.,
#        1963., 1964., 1965., 1966., 1967., 1968., 1969., 1970., 1971.,
#        1972., 1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980.,
#        1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989.,
#        1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998.,
#        1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007.,
#        2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022., 2023., 2024., 2025.,
#          nan])

# %% [markdown]
# Maintenant nous avons un dataframe unique pour les logements de l'ademe

# %% [markdown]
# ### Harmonisation des adresses des logements car c'est ce qui servira dans la fusion des données externes que nous allons utiliser ulterieurement

# %%
display(data_ademe[['adresse_ban', 'etiquette_dpe']])
# Out:
#                                               adresse_ban etiquette_dpe
# 0           Route de Rochelin 69790 Saint-Clément-de-Vers             E
# 1                                               Propières             G
# 2       290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...             G
# 3        Route des Proles 69790 Saint-Bonnet-des-Bruyères             C
# 4              2101 Route du Saint-Rigaud 69790 Propières             G
# ...                                                   ...           ...
# 447481               103 Route de la Joanna 69126 Brindas             A
# 447482                  Chemin de la Madone 69126 Brindas             A
# 447483                     Chemin du Moncel 69126 Brindas             A
# 447484                 60 Chemin des Andres 69126 Brindas             A
# 447485           10 Chemin de la Grand Cour 69126 Brindas             A
#
# [447486 rows x 2 columns]

# %%
import re
import pandas as pd

def is_complete(address):
    if pd.isna(address):
        return False
    address = address.strip()
    pattern = r"^\s*\d{0,4}\s*[A-Za-zÀ-ÖØ-öø-ÿ'’\-\s]+\s+\d{5}\s+[A-Za-zÀ-ÖØ-öø-ÿ'’\-\s]+$"
    return bool(re.match(pattern, address))

# Vérification des adresses valides
print(f"Avant filtrage : {data_ademe.shape}")
data_ademe["adresse_valide"] = data_ademe["adresse_ban"].apply(is_complete)
print(data_ademe["adresse_valide"].value_counts(normalize=True))

# Filtrage
data_ademe_adresse = data_ademe.loc[data_ademe["adresse_valide"]].copy()
print(f"Après filtrage : {data_ademe_adresse.shape}")
# Out:
# Avant filtrage : (447486, 85)
# adresse_valide
# True     0.970712
# False    0.029288
# Name: proportion, dtype: float64
# Après filtrage : (434380, 86)

# %%
data_ademe['adresse_ban'].nunique()
# Out:
# 86787

# %%
data_ademe_adresse['adresse_ban'].nunique()
# Out:
# 83118

# %%
data_ademe_adresse.to_csv("ademe_adresses_filtrees.csv", index=False)

# %%
import pandas as pd
import requests
import time
import concurrent.futures
import random

# PARAMÈTRES GÉNÉRAUX 
ENTREE_CSV = "ademe_adresses_filtrees.csv"  
SORTIE_CSV = "ademe_adresses_normalisees.csv" 
BATCH_SIZE = 5000   # nb d’adresses à traiter entre deux sauvegardes
MAX_WORKERS = 10    # threads simultanés
PAUSE = (0.1, 0.3)  # pause aléatoire entre requêtes (évite saturation API)
TIMEOUT = 8         # timeout API
RETRY = 3           # nb max de tentatives par adresse

# === LECTURE ===
print("Lecture des adresses...")
data = pd.read_csv(ENTREE_CSV, dtype=str, low_memory=False)
adresses = data["adresse_ban"].dropna().unique().tolist()
print(f"{len(adresses):,} adresses uniques à normaliser.")

# === FONCTION DE REQUÊTE BAN ===
def normaliser_adresse(adresse):
    if pd.isna(adresse) or not adresse.strip():
        return None

    for tentative in range(RETRY):
        try:
            r = requests.get(
                "https://api-adresse.data.gouv.fr/search/",
                params={"q": adresse, "limit": 1},
                timeout=TIMEOUT
            )
            if r.status_code == 200:
                js = r.json()
                feats = js.get("features", [])
                if not feats:
                    return None
                props = feats[0]["properties"]
                geom = feats[0]["geometry"]["coordinates"]
                return {
                    "adresse_ban": adresse,
                    "adresse_norm": props.get("label"),
                    "score": props.get("score"),
                    "latitude": geom[1],
                    "longitude": geom[0]
                }
            elif r.status_code == 429:
                # trop de requêtes : pause exponentielle
                wait = 2 ** tentative + random.random()
                print(f" 429 Too Many Requests – pause {wait:.1f}s")
                time.sleep(wait)
            else:
                print(f" HTTP {r.status_code} pour {adresse}")
                return None
        except Exception as e:
            print(f" Erreur tentative {tentative+1}/{RETRY} : {e}")
            time.sleep(0.5)
    return None

# === TRAITEMENT PAR LOTS ===
resultats = []
total = len(adresses)

for start in range(0, total, BATCH_SIZE):
    fin = min(start + BATCH_SIZE, total)
    batch = adresses[start:fin]
    print(f" Traitement des adresses {start:,} → {fin:,}...")

    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(normaliser_adresse, adr) for adr in batch]
        for i, f in enumerate(concurrent.futures.as_completed(futures), 1):
            res = f.result()
            if res:
                resultats.append(res)
            if i % 500 == 0:
                print(f"  → {i}/{len(batch)} terminées")
            time.sleep(random.uniform(*PAUSE))

    # sauvegarde intermédiaire
    df_partiel = pd.DataFrame(resultats)
    df_partiel.to_csv(SORTIE_CSV, index=False)
    print(f" Sauvegarde intermédiaire ({len(df_partiel):,} lignes)")

print("\n Normalisation terminée !")
df_final = pd.DataFrame(resultats)
df_final.to_csv(SORTIE_CSV, index=False)
print(f"Fichier final sauvegardé : {SORTIE_CSV} ({len(df_final):,} adresses)")
# Out:
# Lecture des adresses...
# 83,118 adresses uniques à normaliser.
# 🧭 Traitement des adresses 0 → 5,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (5,000 lignes)
# 🧭 Traitement des adresses 5,000 → 10,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
# ⚠️ HTTP 504 pour 16 Boulevard Jean XXIII 69008 Lyon
# ⚠️ HTTP 504 pour 31 Rue Saint Maurice 69008 Lyon
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (9,998 lignes)
# 🧭 Traitement des adresses 10,000 → 15,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (14,998 lignes)
# 🧭 Traitement des adresses 15,000 → 20,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (19,998 lignes)
# 🧭 Traitement des adresses 20,000 → 25,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (24,998 lignes)
# 🧭 Traitement des adresses 25,000 → 30,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (29,998 lignes)
# 🧭 Traitement des adresses 30,000 → 35,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (34,998 lignes)
# 🧭 Traitement des adresses 35,000 → 40,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (39,998 lignes)
# 🧭 Traitement des adresses 40,000 → 45,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
# ⚠️ HTTP 504 pour 1a Rue du Vieux Cep 69400 Limas
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (44,997 lignes)
# 🧭 Traitement des adresses 45,000 → 50,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
# ⚠️ HTTP 504 pour 1 Rue Gaston Bachelard 69120 Vaulx-en-Velin
#   → 4000/5000 terminées
#   → 4500/5000 terminées
# ⚠️ HTTP 504 pour 3bis Rue du Vingtain 69890 La Tour-de-Salvagny
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (49,995 lignes)
# 🧭 Traitement des adresses 50,000 → 55,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
# ⚠️ HTTP 504 pour 151 Route de Saint-Lager 69220 Charentay
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (54,994 lignes)
# 🧭 Traitement des adresses 55,000 → 60,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (59,994 lignes)
# 🧭 Traitement des adresses 60,000 → 65,000...
# ⚠️ HTTP 504 pour 2 Quai de la Chapelle 69210 Sain-Bel
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
#   → 2000/5000 terminées
#   → 2500/5000 terminées
# ⚠️ HTTP 504 pour 31 Rue de la Gare 69830 Saint-Georges-de-Reneins
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (64,992 lignes)
# 🧭 Traitement des adresses 65,000 → 70,000...
#   → 500/5000 terminées
#   → 1000/5000 terminées
#   → 1500/5000 terminées
# ⚠️ HTTP 504 pour 16 Rue Léo Lagrange 69190 Saint-Fons
# ⚠️ HTTP 504 pour 39 Rue du Labour 69190 Saint-Fons
#   → 2000/5000 terminées
# ⚠️ HTTP 504 pour 11 Allée des Cerisiers 69450 Saint-Cyr-au-Mont-d'Or
#   → 2500/5000 terminées
# ⚠️ HTTP 504 pour 6 Chemin la Font 69280 Marcy-l'Étoile
#   → 3000/5000 terminées
#   → 3500/5000 terminées
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
# ⚠️ Erreur tentative 1/3 : ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
#   → 4000/5000 terminées
# ⚠️ HTTP 504 pour 670 Route de Lucenay 69480 Anse
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (69,987 lignes)
# 🧭 Traitement des adresses 70,000 → 75,000...
#   → 500/5000 terminées
# ⚠️ HTTP 504 pour 1 Rue Salvador Allende 69600 Oullins-Pierre-Bénite
#   → 1000/5000 terminées
# ⚠️ HTTP 504 pour 7 Rue Albert Schweitzer 69600 Oullins
#   → 1500/5000 terminées
# ⚠️ HTTP 504 pour 13 Rue de la Bussière 69600 Oullins-Pierre-Bénite
#   → 2000/5000 terminées
#   → 2500/5000 terminées
#   → 3000/5000 terminées
#   → 3500/5000 terminées
#   → 4000/5000 terminées
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (74,984 lignes)
# 🧭 Traitement des adresses 75,000 → 80,000...
#   → 500/5000 terminées
# ⚠️ HTTP 504 pour 30 Chemin des Grandes Bruyères 69260 Charbonnières-les-Bains
#   → 1000/5000 terminées
#   → 1500/5000 terminées
# ⚠️ HTTP 504 pour 41 Rue Lucien Cozon 69630 Chaponost
# ⚠️ HTTP 504 pour 20 Lotissement le Parc 69630 Chaponost
#   → 2000/5000 terminées
#   → 2500/5000 terminées
# ⚠️ HTTP 504 pour 116 Grande rue de Saint Clair 69300 Caluire-et-Cuire
#   → 3000/5000 terminées
#   → 3500/5000 terminées
# ⚠️ HTTP 504 pour 17 Rue de l'Economie 69500 Bron
# ⚠️ HTTP 504 pour Rue Gaston Maurin 69500 Bron
#   → 4000/5000 terminées
# ⚠️ HTTP 504 pour 8 Avenue de la Grande ArmÃ e 69500 Bron
#   → 4500/5000 terminées
#   → 5000/5000 terminées
# 💾 Sauvegarde intermédiaire (79,977 lignes)
# 🧭 Traitement des adresses 80,000 → 83,118...
# ⚠️ HTTP 504 pour 10 Rue Jacques 69250 Neuville-sur-Saône
#   → 500/3118 terminées
# ⚠️ HTTP 504 pour 13 Avenue Paul Delorme 69580 Sathonay-Camp
#   → 1000/3118 terminées
#   → 1500/3118 terminées
#   → 2000/3118 terminées
#   → 2500/3118 terminées
#   → 3000/3118 terminées
# 💾 Sauvegarde intermédiaire (83,093 lignes)
#
#  Normalisation terminée !
# Fichier final sauvegardé : ademe_adresses_normalisees.csv (83,093 adresses)

# %%
df_final.head()
# Out:
#                                          adresse_ban  \
# 0  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...
# 1  172 Chemin de la Riviere 69790 Saint-Igny-de-Vers
# 2  Route de Saint Bonnet des Bruyères 69790 Aigue...
# 3   Route des Proles 69790 Saint-Bonnet-des-Bruyères
# 4         2101 Route du Saint-Rigaud 69790 Propières
#
#                                         adresse_norm     score   latitude  \
# 0  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...  0.936032  46.266415
# 1  172 Chemin de la Rivière 69790 Saint-Igny-de-Vers  0.942504  46.236696
# 2  Route de Saint Bonnet des Bruyères 69790 Aigue...  0.943299  46.277197
# 3   Route des Proles 69790 Saint-Bonnet-des-Bruyères  0.943641  46.274676
# 4         2101 route du saint-rigaud 69790 Propières  0.945998  46.198515
#
#    longitude
# 0   4.502530
# 1   4.441573
# 2   4.434760
# 3   4.474832
# 4   4.457319

# %% [markdown]
# ## fusion des données avec les adresses normalisées

# %%
import pandas as pd

# Exemple : lecture des deux fichiers
data_ademe_adresse = pd.read_csv("ademe_adresses_filtrees.csv", dtype=str)
df_norm = pd.read_csv("ademe_adresses_normalisees.csv", dtype=str)

# Vérification rapide
print(f"Données ADEME : {data_ademe_adresse.shape}")
print(f"Données normalisées : {df_norm.shape}")

# Fusion sur la clé commune : "adresse_ban"
data_ademe_f = data_ademe_adresse.merge(
    df_norm,
    on="adresse_ban",
    how="left",        
    validate="m:1"     
)

print(f"Fusion terminée : {data_ademe_f.shape}")
print(data_ademe_f[["adresse_ban", "adresse_norm", "score", "latitude", "longitude"]].head())

# Sauvegarde
data_ademe_f.to_csv("ademe_adresse_geo.csv", index=False)
# Out:
# Données ADEME : (434380, 86)
# Données normalisées : (83093, 5)
# Fusion terminée : (434380, 90)
#                                          adresse_ban  \
# 0      Route de Rochelin 69790 Saint-Clément-de-Vers
# 1  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...
# 2   Route des Proles 69790 Saint-Bonnet-des-Bruyères
# 3         2101 Route du Saint-Rigaud 69790 Propières
# 4   Chemin du Vernay 69790 Saint-Bonnet-des-Bruyères
#
#                                         adresse_norm               score  \
# 0      Route de Rochelin 69790 Saint-Clément-de-Vers  0.9421972727272726
# 1  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...  0.9360318181818181
# 2   Route des Proles 69790 Saint-Bonnet-des-Bruyères   0.943640909090909
# 3         2101 route du saint-rigaud 69790 Propières  0.9459981818181816
# 4   Chemin du Vernay 69790 Saint-Bonnet-des-Bruyères  0.9360318181818181
#
#     latitude longitude
# 0  46.228911  4.399445
# 1  46.266415   4.50253
# 2  46.274676  4.474832
# 3  46.198515  4.457319
# 4  46.267745  4.501981

# %%
data_ademe_f.shape
# Out:
# (434380, 90)

# %%
print(list(data_ademe_f.columns))
# Out:
# ['score_ban', 'conso_auxiliaires_ep', 'cout_eclairage', 'conso_auxiliaires_ef', 'statut_geocodage', 'ventilation_posterieure_2012', 'cout_chauffage', 'conso_5_usages_par_m2_ep', 'date_etablissement_dpe', 'conso_ecs_ef_energie_n1', 'emission_ges_chauffage', 'conso_5_usages_par_m2_ef', 'conso_chauffage_ef_energie_n1', 'qualite_isolation_menuiseries', 'date_reception_dpe', 'cout_total_5_usages_energie_n1', 'cout_ecs_energie_n1', 'qualite_isolation_plancher_bas', 'modele_dpe', 'qualite_isolation_enveloppe', 'type_energie_n1', 'emission_ges_eclairage', 'code_postal_ban', 'emission_ges_ecs', 'conso_5_usages_ef', 'conso_5_usages_ef_energie_n1', 'code_insee_ban', 'conso_5_usages_ep', 'date_fin_validite_dpe', 'code_region_ban', 'version_dpe', 'coordonnee_cartographique_x_ban', 'type_energie_principale_ecs', 'adresse_ban', '_rand', 'production_electricite_pv_kwhep_par_an', 'nombre_niveau_logement', 'surface_habitable_logement', 'cout_ecs', 'emission_ges_5_usages_energie_n1', 'emission_ges_5_usages_par_m2', 'complement_adresse_logement', 'cout_auxiliaires', 'emission_ges_refroidissement', 'hauteur_sous_plafond', 'conso_chauffage_ef', 'nom_commune_ban', '_geopoint', 'date_visite_diagnostiqueur', 'type_batiment', 'conso_ecs_ep', 'conso_ecs_ef', 'emission_ges_5_usages', 'date_derniere_modification_dpe', 'etiquette_ges', 'identifiant_ban', 'ubat_w_par_m2_k', 'nom_commune_brut', 'etiquette_dpe', 'code_departement_ban', 'methode_application_dpe', 'adresse_brut', 'cout_total_5_usages', 'conso_refroidissement_ef', 'conso_eclairage_ef', 'emission_ges_ecs_energie_n1', 'cout_refroidissement', 'conso_chauffage_ep', 'conso_eclairage_ep', 'qualite_isolation_murs', 'conso_refroidissement_ep', 'type_energie_principale_chauffage', 'numero_dpe', '_i', 'emission_ges_chauffage_energie_n1', 'cout_chauffage_energie_n1', 'coordonnee_cartographique_y_ban', 'code_postal_brut', 'emission_ges_auxiliaires', '_score', 'categorie_enr', 'nom_rue_ban', 'nombre_appartement', 'surface_habitable_immeuble', 'annee_construction', 'adresse_valide', 'adresse_norm', 'score', 'latitude', 'longitude']

# %%
colonnes_choisies = [
    # Identification bâtiment
    "date_reception_dpe", "conso_auxiliaires_ef", "cout_eclairage","cout_chauffage","conso_5_usages_par_m2_ef","emission_ges_chauffage","modele_dpe","type_energie_n1",
    "emission_ges_eclairage","code_postal_ban","emission_ges_ecs","conso_5_usages_ef","surface_habitable_logement","cout_ecs","emission_ges_5_usages_par_m2","cout_auxiliaires",
    "emission_ges_refroidissement","conso_chauffage_ef","type_batiment","conso_ecs_ef","emission_ges_5_usages","etiquette_ges","etiquette_dpe","cout_total_5_usages","conso_refroidissement_ef",
    "conso_eclairage_ef","cout_refroidissement","type_energie_principale_chauffage","numero_dpe","numero_dpe", "adresse_ban", "adresse_norm", "latitude", "longitude",
]

# %%
# selection des colonnes de l'ademe
ademe_final = data_ademe_f[colonnes_choisies]
ademe_final.shape
# Out:
# (434380, 34)

# %%
pd.options.display.max_columns = None
ademe_final.head()
# Out:
#   date_reception_dpe conso_auxiliaires_ef cout_eclairage cout_chauffage  \
# 0         2022-05-14                928.9           66.4         2164.5
# 1         2021-11-24                  0.0           15.3         2384.4
# 2         2021-08-21                754.2           63.1         1338.6
# 3         2021-11-30                376.6           48.8         4588.1
# 4         2021-09-02                291.9           54.1         3193.8
#
#   conso_5_usages_par_m2_ef emission_ges_chauffage  \
# 0                    203.0                 7671.2
# 1                    470.0                 1286.4
# 2                     51.0                  517.7
# 3                    394.0                16260.5
# 4                    358.0                11319.1
#
#                       modele_dpe   type_energie_n1 emission_ges_eclairage  \
# 0  DPE 3CL 2021 méthode logement  Fioul domestique                   17.1
# 1  DPE 3CL 2021 méthode logement     Bois – Bûches                    6.4
# 2  DPE 3CL 2021 méthode logement       Électricité                   21.3
# 3  DPE 3CL 2021 méthode logement  Fioul domestique                   17.2
# 4  DPE 3CL 2021 méthode logement       Électricité                   13.4
#
#   code_postal_ban emission_ges_ecs conso_5_usages_ef  \
# 0           69790            759.3           27197.3
# 1           69790             87.1           23582.8
# 2           69790             59.6            8533.5
# 3           69790            141.1           52983.8
# 4           69790            120.1           37269.5
#
#   surface_habitable_logement cout_ecs emission_ges_5_usages_par_m2  \
# 0                      133.6    214.2                         63.0
# 1                       50.1    219.7                         27.0
# 2                      166.2    187.2                          3.0
# 3                      134.2    424.1                        122.0
# 4                      104.1    516.6                        110.0
#
#   cout_auxiliaires emission_ges_refroidissement conso_chauffage_ef  \
# 0            248.2                          0.0            23676.5
# 1              0.0                          0.0            22149.8
# 2            154.0                          0.0             6553.6
# 3             73.6                          0.0            50186.8
# 4             81.6                          0.0            34935.6
#
#   type_batiment conso_ecs_ef emission_ges_5_usages etiquette_ges  \
# 0        maison       2343.4                8507.0             E
# 1        maison       1339.8                1379.9             C
# 2        maison        916.6                 646.9             A
# 3        maison       2170.8               16442.9             G
# 4        maison       1848.4               11471.3             G
#
#   etiquette_dpe cout_total_5_usages conso_refroidissement_ef  \
# 0             E              2693.3                      0.0
# 1             G              2619.4                      0.0
# 2             C              1743.0                      0.0
# 3             G              5134.6                      0.0
# 4             G              3846.1                      0.0
#
#   conso_eclairage_ef cout_refroidissement type_energie_principale_chauffage  \
# 0              248.5                  0.0                  Fioul domestique
# 1               93.2                  0.0                       Électricité
# 2              309.1                  0.0                       Électricité
# 3              249.7                  0.0                       Électricité
# 4              193.5                  0.0                       Électricité
#
#       numero_dpe     numero_dpe  \
# 0  2269E1049302M  2269E1049302M
# 1  2169E0761678Z  2169E0761678Z
# 2  2169E0199264R  2169E0199264R
# 3  2169E0806561G  2169E0806561G
# 4  2169E0251506Z  2169E0251506Z
#
#                                          adresse_ban  \
# 0      Route de Rochelin 69790 Saint-Clément-de-Vers
# 1  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...
# 2   Route des Proles 69790 Saint-Bonnet-des-Bruyères
# 3         2101 Route du Saint-Rigaud 69790 Propières
# 4   Chemin du Vernay 69790 Saint-Bonnet-des-Bruyères
#
#                                         adresse_norm   latitude longitude
# 0      Route de Rochelin 69790 Saint-Clément-de-Vers  46.228911  4.399445
# 1  290 Chemin du Vernay 69790 Saint-Bonnet-des-Br...  46.266415   4.50253
# 2   Route des Proles 69790 Saint-Bonnet-des-Bruyères  46.274676  4.474832
# 3         2101 route du saint-rigaud 69790 Propières  46.198515  4.457319
# 4   Chemin du Vernay 69790 Saint-Bonnet-des-Bruyères  46.267745  4.501981

# %%
ademe_final.to_csv("donnees_ademe_finales_69.csv", index=False)

# %% [markdown]
# # 2e partie : données ENEDIS

# %%
# import des données enedis
donnees_enedis = pd.read_csv("consommation_annuelle_residentielle_par_adresse.csv", sep=";")
donnees_enedis.head()
# Out:
# C:\Users\Surface\AppData\Local\Temp\ipykernel_1988\1911998734.py:2: DtypeWarning: Columns (1,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   donnees_enedis = pd.read_csv("consommation_annuelle_residentielle_par_adresse.csv", sep=";")
#    Année  Code IRIS  Nom IRIS  Numéro de voie Indice de répétition  \
# 0   2018  920040601  Renoir i             8.0                  NaN
# 1   2018  920040601  Renoir i             7.0                  NaN
# 2   2018  920040601  Renoir i             6.0                  NaN
# 3   2018  920040604     Metro           184.0                  NaN
# 4   2018  920040604     Metro           154.0                  NaN
#
#   Type de voie Libellé de voie  Code Commune         Nom Commune  \
# 0        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 1        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 2        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 3    BOULEVARD        VOLTAIRE         92004  ASNIERES-SUR-SEINE
# 4    BOULEVARD        VOLTAIRE         92004  ASNIERES-SUR-SEINE
#
#   Segment de client  Nombre de logements  \
# 0       RESIDENTIEL                   10
# 1       RESIDENTIEL                   10
# 2       RESIDENTIEL                   10
# 3       RESIDENTIEL                   29
# 4       RESIDENTIEL                   12
#
#    Consommation annuelle totale de l'adresse (MWh)  \
# 0                                           18.925
# 1                                           19.579
# 2                                           18.886
# 3                                           35.316
# 4                                           28.286
#
#    Consommation annuelle moyenne par logement de l'adresse (MWh)  \
# 0                                              1.893
# 1                                              1.958
# 2                                              1.889
# 3                                              1.218
# 4                                              2.357
#
#    Consommation annuelle moyenne de la commune (MWh)                 Adresse  \
# 0                                              3.346        8 ALLEE VISCONTI
# 1                                              3.346        7 ALLEE VISCONTI
# 2                                              3.346        6 ALLEE VISCONTI
# 3                                              3.346  184 BOULEVARD VOLTAIRE
# 4                                              3.346  154 BOULEVARD VOLTAIRE
#
#      Code EPCI  Code Département  Code Région  Tri des adresses
# 0  200054781.0              92.0         11.0            420021
# 1  200054781.0              92.0         11.0            420022
# 2  200054781.0              92.0         11.0            420023
# 3  200054781.0              92.0         11.0            420036
# 4  200054781.0              92.0         11.0            420043

# %%
donnees_enedis_69 = donnees_enedis[donnees_enedis['Code Département'] == 69]
donnees_enedis_69.head()
donnees_enedis_69.to_csv("donnees_enedis_69.csv", index=False, encoding="utf-8")

# %%
donnees_enedis_69['Adresse'].value_counts()
# Out:
# Adresse
# 1 RUE DU 8 MAI 1945           32
# 2 RUE VICTOR HUGO             29
# 4 RUE DE LA REPUBLIQUE        28
# 20 RUE DE LA REPUBLIQUE       28
# 3 RUE DU 8 MAI 1945           27
#                               ..
# 11 RUE DE THIZY                1
# 5 RUE PROFESSEUR TAVERNIER     1
# 2 RUE FRANCOIS GENIN           1
# 1 E QUAI GEORGES LEVY          1
# 26 RUE DE LA CHAUX             1
# Name: count, Length: 29040, dtype: int64

# %% [markdown]
# ### normalisation des adresses de enedis pour faciliter plus tard la jointure avec les données de l'ademe

# %%
import pandas as pd
import requests
import time
import random
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path

#   PARAMÈTRES GÉNÉRAUX

INPUT_FILE = "donnees_enedis_69.csv"
OUTPUT_FILE = "donnees_enedis_69_normalise.csv"
CACHE_FILE = "cache_ban.json"
MAX_WORKERS = 10  # threads simultanés
SAVE_EVERY = 2000  # sauvegarde automatique tous les X adresses
SLEEP_BETWEEN = (0.05, 0.2)  # pour ne pas saturer l'API

#  CHARGEMENT DES DONNÉES

print("Chargement des données Enedis...")
enedis = pd.read_csv(INPUT_FILE, sep=",", dtype=str)
for col in ["Numéro de voie", "Type de voie", "Libellé de voie", "Code Commune", "Nom Commune"]:
    enedis[col] = enedis[col].fillna("").str.strip()

# Construction de l’adresse à normaliser
enedis["adresse_combinee"] = (
    enedis["Numéro de voie"] + " " +
    enedis["Type de voie"] + " " +
    enedis["Libellé de voie"] + ", " +
    enedis["Code Commune"] + " " +
    enedis["Nom Commune"]
).str.replace(r"\s+", " ", regex=True).str.strip()

print(f"{len(enedis):,} adresses à traiter")

#  GESTION DU CACHE

cache = {}
if Path(CACHE_FILE).exists():
    print("Cache local trouvé, chargement...")
    cache = json.loads(Path(CACHE_FILE).read_text())

def save_cache():
    Path(CACHE_FILE).write_text(json.dumps(cache))

# FONCTION BAN AVEC RETRY

def normaliser_adresse_ban(adresse):
    adresse = adresse.strip()
    if not adresse:
        return None

    # Si déjà dans le cache
    if adresse in cache:
        return cache[adresse]

    url = "https://api-adresse.data.gouv.fr/search/"
    params = {"q": adresse, "limit": 1}

    for attempt in range(3):
        try:
            r = requests.get(url, params=params, timeout=8)
            if r.status_code == 200:
                data = r.json()
                if data["features"]:
                    feat = data["features"][0]
                    props = feat["properties"]
                    geom = feat["geometry"]["coordinates"]
                    res = {
                        "adresse_norm": props.get("label"),
                        "score": props.get("score"),
                        "latitude": geom[1],
                        "longitude": geom[0],
                        "code_insee": props.get("citycode"),
                        "code_postal": props.get("postcode"),
                    }
                    cache[adresse] = res
                    time.sleep(random.uniform(*SLEEP_BETWEEN))
                    return res
            time.sleep(0.2)
        except requests.RequestException:
            time.sleep(0.5)
    cache[adresse] = None
    return None

# ⚡  MULTITHREADING

results = []
to_process = enedis["adresse_combinee"].unique().tolist()
print(f"Lancement du géocodage BAN sur {len(to_process):,} adresses uniques...")

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(normaliser_adresse_ban, adr): adr for adr in to_process}
    done_count = 0
    for future in as_completed(futures):
        done_count += 1
        if done_count % SAVE_EVERY == 0:
            save_cache()
            print(f"{done_count:,} adresses traitées — cache sauvegardé")
        if done_count % 500 == 0:
            print(f"Progression : {done_count:,}/{len(to_process):,}")
    save_cache()

print("Géocodage terminé !")


#  CRÉATION DU DATAFRAME FINAL

# Conversion du cache en DataFrame
norm_data = []
for adr, res in cache.items():
    if res:
        res["adresse_combinee"] = adr
        norm_data.append(res)

enedis_norm = pd.DataFrame(norm_data)

# Jointure avec les données d’origine
enedis_geo = enedis.merge(enedis_norm, on="adresse_combinee", how="left")

# Sauvegarde finale
enedis_geo.to_csv(OUTPUT_FILE, index=False)
print(f" Données enrichies sauvegardées dans {OUTPUT_FILE}")
# Out:
# Chargement des données Enedis...
# 165,267 adresses à traiter
# Lancement du géocodage BAN sur 52,231 adresses uniques...
# Progression : 500/52,231
# Progression : 1,000/52,231
# Progression : 1,500/52,231
# 2,000 adresses traitées — cache sauvegardé
# Progression : 2,000/52,231
# Progression : 2,500/52,231
# Progression : 3,000/52,231
# Progression : 3,500/52,231
# 4,000 adresses traitées — cache sauvegardé
# Progression : 4,000/52,231
# Progression : 4,500/52,231
# Progression : 5,000/52,231
# Progression : 5,500/52,231
# 6,000 adresses traitées — cache sauvegardé
# Progression : 6,000/52,231
# Progression : 6,500/52,231
# Progression : 7,000/52,231
# Progression : 7,500/52,231
# 8,000 adresses traitées — cache sauvegardé
# Progression : 8,000/52,231
# Progression : 8,500/52,231
# Progression : 9,000/52,231
# Progression : 9,500/52,231
# 10,000 adresses traitées — cache sauvegardé
# Progression : 10,000/52,231
# Progression : 10,500/52,231
# Progression : 11,000/52,231
# Progression : 11,500/52,231
# 12,000 adresses traitées — cache sauvegardé
# Progression : 12,000/52,231
# Progression : 12,500/52,231
# Progression : 13,000/52,231
# Progression : 13,500/52,231
# 14,000 adresses traitées — cache sauvegardé
# Progression : 14,000/52,231
# Progression : 14,500/52,231
# Progression : 15,000/52,231
# Progression : 15,500/52,231
# 16,000 adresses traitées — cache sauvegardé
# Progression : 16,000/52,231
# Progression : 16,500/52,231
# Progression : 17,000/52,231
# Progression : 17,500/52,231
# 18,000 adresses traitées — cache sauvegardé
# Progression : 18,000/52,231
# Progression : 18,500/52,231
# Progression : 19,000/52,231
# Progression : 19,500/52,231
# 20,000 adresses traitées — cache sauvegardé
# Progression : 20,000/52,231
# Progression : 20,500/52,231
# Progression : 21,000/52,231
# Progression : 21,500/52,231
# 22,000 adresses traitées — cache sauvegardé
# Progression : 22,000/52,231
# Progression : 22,500/52,231
# Progression : 23,000/52,231
# Progression : 23,500/52,231
# 24,000 adresses traitées — cache sauvegardé
# Progression : 24,000/52,231
# Progression : 24,500/52,231
# Progression : 25,000/52,231
# Progression : 25,500/52,231
# 26,000 adresses traitées — cache sauvegardé
# Progression : 26,000/52,231
# Progression : 26,500/52,231
# Progression : 27,000/52,231
# Progression : 27,500/52,231
# 28,000 adresses traitées — cache sauvegardé
# Progression : 28,000/52,231
# Progression : 28,500/52,231
# Progression : 29,000/52,231
# Progression : 29,500/52,231
# 30,000 adresses traitées — cache sauvegardé
# Progression : 30,000/52,231
# Progression : 30,500/52,231
# Progression : 31,000/52,231
# Progression : 31,500/52,231
# 32,000 adresses traitées — cache sauvegardé
# Progression : 32,000/52,231
# Progression : 32,500/52,231
# Progression : 33,000/52,231
# Progression : 33,500/52,231
# 34,000 adresses traitées — cache sauvegardé
# Progression : 34,000/52,231
# Progression : 34,500/52,231
# Progression : 35,000/52,231
# Progression : 35,500/52,231
# 36,000 adresses traitées — cache sauvegardé
# Progression : 36,000/52,231
# Progression : 36,500/52,231
# Progression : 37,000/52,231
# Progression : 37,500/52,231
# 38,000 adresses traitées — cache sauvegardé
# Progression : 38,000/52,231
# Progression : 38,500/52,231
# Progression : 39,000/52,231
# Progression : 39,500/52,231
# 40,000 adresses traitées — cache sauvegardé
# Progression : 40,000/52,231
# Progression : 40,500/52,231
# Progression : 41,000/52,231
# Progression : 41,500/52,231
# 42,000 adresses traitées — cache sauvegardé
# Progression : 42,000/52,231
# Progression : 42,500/52,231
# Progression : 43,000/52,231
# Progression : 43,500/52,231
# 44,000 adresses traitées — cache sauvegardé
# Progression : 44,000/52,231
# Progression : 44,500/52,231
# Progression : 45,000/52,231
# Progression : 45,500/52,231
# 46,000 adresses traitées — cache sauvegardé
# Progression : 46,000/52,231
# Progression : 46,500/52,231
# Progression : 47,000/52,231
# Progression : 47,500/52,231
# 48,000 adresses traitées — cache sauvegardé
# Progression : 48,000/52,231
# Progression : 48,500/52,231
# Progression : 49,000/52,231
# Progression : 49,500/52,231
# 50,000 adresses traitées — cache sauvegardé
# Progression : 50,000/52,231
# Progression : 50,500/52,231
# Progression : 51,000/52,231
# Progression : 51,500/52,231
# 52,000 adresses traitées — cache sauvegardé
# Progression : 52,000/52,231
# Géocodage terminé !
#  Données enrichies sauvegardées dans donnees_enedis_69_normalise.csv

# %%
enedis_geo.head()
# Out:
#   Année  Code IRIS Nom IRIS Numéro de voie Indice de répétition Type de voie  \
# 0  2018  690400101   Centre           46.0                  NaN       AVENUE
# 1  2018  690400101   Centre           34.0                  NaN       AVENUE
# 2  2018  690400102  Contour           13.0                  NaN          RUE
# 3  2018  690400101   Centre            8.0                  NaN          RUE
# 4  2018  690400101   Centre           10.0                    B       AVENUE
#
#       Libellé de voie Code Commune             Nom Commune Segment de client  \
# 0        DE MONTLOUIS        69040  CHAMPAGNE-AU-MONT-D'OR       RESIDENTIEL
# 1        DE MONTLOUIS        69040  CHAMPAGNE-AU-MONT-D'OR       RESIDENTIEL
# 2  JEAN CLAUDE BARTET        69040  CHAMPAGNE-AU-MONT-D'OR       RESIDENTIEL
# 3        JOANNES CHOL        69040  CHAMPAGNE-AU-MONT-D'OR       RESIDENTIEL
# 4            LANESSAN        69040  CHAMPAGNE-AU-MONT-D'OR       RESIDENTIEL
#
#    ... Code Département Code Région Tri des adresses  \
# 0  ...             69.0        84.0           468802
# 1  ...             69.0        84.0           468804
# 2  ...             69.0        84.0           468810
# 3  ...             69.0        84.0           468814
# 4  ...             69.0        84.0           468822
#
#                                     adresse_combinee  \
# 0  46.0 AVENUE DE MONTLOUIS, 69040 CHAMPAGNE-AU-M...
# 1  34.0 AVENUE DE MONTLOUIS, 69040 CHAMPAGNE-AU-M...
# 2  13.0 RUE JEAN CLAUDE BARTET, 69040 CHAMPAGNE-A...
# 3  8.0 RUE JOANNES CHOL, 69040 CHAMPAGNE-AU-MONT-...
# 4  10.0 AVENUE LANESSAN, 69040 CHAMPAGNE-AU-MONT-...
#
#                                         adresse_norm     score   latitude  \
# 0   Avenue de Montlouis 69410 Champagne-au-Mont-d'Or  0.706494  45.795658
# 1   Avenue de Montlouis 69410 Champagne-au-Mont-d'Or  0.706494  45.795658
# 2  Rue Jean-Claude Bartet 69410 Champagne-au-Mont...  0.714307  45.791613
# 3      Rue Joannès Chol 69410 Champagne-au-Mont-d'Or  0.702386  45.796866
# 4    Avenue de Lanessan 69410 Champagne-au-Mont-d'Or  0.688775  45.795725
#
#   longitude code_insee code_postal
# 0  4.785021      69040       69410
# 1  4.785021      69040       69410
# 2  4.794612      69040       69410
# 3  4.791910      69040       69410
# 4  4.791754      69040       69410
#
# [5 rows x 26 columns]

# %%
enedis_geo.shape
# Out:
# (165267, 26)

# %%
enedis_geo.columns
# Out:
# Index(['Année', 'Code IRIS', 'Nom IRIS', 'Numéro de voie',
#        'Indice de répétition', 'Type de voie', 'Libellé de voie',
#        'Code Commune', 'Nom Commune', 'Segment de client',
#        'Nombre de logements',
#        'Consommation annuelle totale de l'adresse (MWh)',
#        'Consommation annuelle moyenne par logement de l'adresse (MWh)',
#        'Consommation annuelle moyenne de la commune (MWh)', 'Adresse',
#        'Code EPCI', 'Code Département', 'Code Région', 'Tri des adresses',
#        'adresse_combinee', 'adresse_norm', 'score', 'latitude', 'longitude',
#        'code_insee', 'code_postal'],
#       dtype='object')

# %%
# selection de colonnes des données enedis
colonnes_choisies = [
    "Année", "adresse_norm", "score", "latitude", "longitude", "code_insee", "code_postal" , "Code Département", "Nombre de logements", "Consommation annuelle totale de l'adresse (MWh)", "Consommation annuelle moyenne par logement de l'adresse (MWh)",
    "Consommation annuelle moyenne de la commune (MWh)"
]

# %%
donnees_enedis_selectionnees = enedis_geo[colonnes_choisies]
donnees_enedis_selectionnees.head()
# Out:
#   Année                                       adresse_norm     score  \
# 0  2018   Avenue de Montlouis 69410 Champagne-au-Mont-d'Or  0.706494
# 1  2018   Avenue de Montlouis 69410 Champagne-au-Mont-d'Or  0.706494
# 2  2018  Rue Jean-Claude Bartet 69410 Champagne-au-Mont...  0.714307
# 3  2018      Rue Joannès Chol 69410 Champagne-au-Mont-d'Or  0.702386
# 4  2018    Avenue de Lanessan 69410 Champagne-au-Mont-d'Or  0.688775
#
#     latitude  longitude code_insee code_postal Code Département  \
# 0  45.795658   4.785021      69040       69410             69.0
# 1  45.795658   4.785021      69040       69410             69.0
# 2  45.791613   4.794612      69040       69410             69.0
# 3  45.796866   4.791910      69040       69410             69.0
# 4  45.795725   4.791754      69040       69410             69.0
#
#   Nombre de logements Consommation annuelle totale de l'adresse (MWh)  \
# 0                  37                                         123.347
# 1                  12                                           62.83
# 2                  16                                         103.763
# 3                  12                                          27.896
# 4                  18                                          42.015
#
#   Consommation annuelle moyenne par logement de l'adresse (MWh)  \
# 0                                              3.334
# 1                                              5.236
# 2                                              6.485
# 3                                              2.325
# 4                                              2.334
#
#   Consommation annuelle moyenne de la commune (MWh)
# 0                                             4.391
# 1                                             4.391
# 2                                             4.391
# 3                                             4.391
# 4                                             4.391

# %%
donnees_enedis_selectionnees.to_csv("donnees_enedis_finales_69.csv", index=False)

# %% [markdown]
# ### données finales

# %% [markdown]
# ici on merge les données finales de Ademe et Enedis pour la suite de nos analyses

# %%
ademe_final = pd.read_csv("donnees_ademe_finales_69.csv")
ademe_final.shape
# Out:
# (434380, 34)

# %%
ademe_final['date_reception_dpe'].sort_values().unique()
# Out:
# array(['2021-07-01', '2021-07-02', '2021-07-03', ..., '2025-10-16',
#        '2025-10-17', '2025-10-20'], shape=(1570,), dtype=object)

# %%
donnees_enedis_selectionnees = pd.read_csv("donnees_enedis_finales_69.csv")
donnees_enedis_selectionnees.shape
# Out:
# (165267, 12)

# %%
nb_doublons = donnees_enedis_selectionnees[["Année", "adresse_norm", "latitude", "longitude", "code_insee", "code_postal" , "Code Département", "Nombre de logements", "Consommation annuelle totale de l'adresse (MWh)", "Consommation annuelle moyenne par logement de l'adresse (MWh)",
    "Consommation annuelle moyenne de la commune (MWh)"]].duplicated().sum()
print(f"Nombre de doublons exacts (toutes colonnes identiques) : {nb_doublons}")
# Out:
# Nombre de doublons exacts (toutes colonnes identiques) : 7

# %%
nb_doublons = ademe_final.duplicated().sum()
print(f"Nombre de doublons exacts (toutes colonnes identiques) : {nb_doublons}")
# Out:
# Nombre de doublons exacts (toutes colonnes identiques) : 0

# %%
print("Doublons ADEME :", ademe_final["adresse_norm"].duplicated().sum())
print("Doublons ENEDIS :", donnees_enedis_selectionnees["adresse_norm", "Année"].duplicated().sum())
# Out:
# Doublons ADEME : 353420
# Doublons ENEDIS : 160888

# %%
ademe_final['adresse_norm'].nunique()
# Out:
# 80959

# %%
donnees_enedis_selectionnees['adresse_norm'].nunique()
# Out:
# 4378

# %%
4378/80959
# Out:
# 0.054076754900628715
